# %% [markdown]
# # 线性回归的从零开始实现
# :label:`sec_linear_scratch`
#
# 在了解线性回归的关键思想之后，我们可以开始通过代码来动手实现线性回归了。
# 在这一节中，(**我们将从零开始实现整个方法，
# 包括数据流水线、模型、损失函数和小批量随机梯度下降优化器**)。
# 虽然现代的深度学习框架几乎可以自动化地进行所有这些工作，但从零开始实现可以确保我们真正知道自己在做什么。
# 同时，了解更细致的工作原理将方便我们自定义模型、自定义层或自定义损失函数。
# 在这一节中，我们将只使用张量和自动求导。
# 在之后的章节中，我们会充分利用深度学习框架的优势，介绍更简洁的实现方式。

# %%
# %matplotlib inline
import random
import torch
from d2l import torch as d2l

# %% [markdown]
# ## 生成数据集
#
# 为了简单起见，我们将[**根据带有噪声的线性模型构造一个人造数据集。**]
# 我们的任务是使用这个有限样本的数据集来恢复这个模型的参数。
# 我们将使用低维数据，这样可以很容易地将其可视化。
# 在下面的代码中，我们生成一个包含1000个样本的数据集，
# 每个样本包含从标准正态分布中采样的2个特征。
# 我们的合成数据集是一个矩阵$\mathbf{X}\in \mathbb{R}^{1000 \times 2}$。
#
# (**我们使用线性模型参数$\mathbf{w} = [2, -3.4]^\top$、$b = 4.2$
# 和噪声项$\epsilon$生成数据集及其标签：
#
# $$\mathbf{y}= \mathbf{X} \mathbf{w} + b + \mathbf\epsilon.$$
# **)
#
# $\epsilon$可以视为模型预测和标签时的潜在观测误差。
# 在这里我们认为标准假设成立，即$\epsilon$服从均值为0的正态分布。
# 为了简化问题，我们将标准差设为0.01。
# 下面的代码生成合成数据集。

# %%
def synthetic_data(w, b, num_examples):  #@save
    """生成y=Xw+b+噪声"""
    X = torch.normal(0, 1, (num_examples, len(w)))
    y = torch.matmul(X, w) + b
    y += torch.normal(0, 0.01, y.shape)
    return X, y.reshape((-1, 1))

# %%
true_w = torch.tensor([2, -3.4])
true_b = 4.2
features, labels = synthetic_data(true_w, true_b, 1000)
# features, labels

# %% [markdown]
# 注意，[**`features`中的每一行都包含一个二维数据样本，
# `labels`中的每一行都包含一维标签值（一个标量）**]。

# %%
print('features:', features[0],'\nlabel:', labels[0])
# features[:, (1)]
# Out:
# features: tensor([0.4609, 0.9344])
# label: tensor([1.9488])

# %% [markdown]
# 通过生成第二个特征`features[:, 1]`和`labels`的散点图，
# 可以直观观察到两者之间的线性关系。

# %%
d2l.set_figsize()
d2l.plt.scatter(features[:, (1)].detach().numpy(), labels.detach().numpy(), 1);

# %% [markdown]
# ## 读取数据集
#
# 回想一下，训练模型时要对数据集进行遍历，每次抽取一小批量样本，并使用它们来更新我们的模型。
# 由于这个过程是训练机器学习算法的基础，所以有必要定义一个函数，
# 该函数能打乱数据集中的样本并以小批量方式获取数据。
#
# 在下面的代码中，我们[**定义一个`data_iter`函数，
# 该函数接收批量大小、特征矩阵和标签向量作为输入，生成大小为`batch_size`的小批量**]。
# 每个小批量包含一组特征和标签。

# %%
def data_iter(batch_size, features, labels):
    num_examples = len(features)
    #print(num_examples)
    indices = list(range(num_examples))
    # print(indices)
    # 这些样本是随机读取的，没有特定的顺序
    random.shuffle(indices)
    # print(indices)

    for i in range(0, num_examples, batch_size):
        batch_indices = torch.tensor(indices[i: min(i + batch_size, num_examples)])
        # print(batch_indices)
        yield features[batch_indices], labels[batch_indices]

# %% [markdown]
# 通常，我们利用GPU并行运算的优势，处理合理大小的“小批量”。
# 每个样本都可以并行地进行模型计算，且每个样本损失函数的梯度也可以被并行计算。
# GPU可以在处理几百个样本时，所花费的时间不比处理一个样本时多太多。
#
# 我们直观感受一下小批量运算：读取第一个小批量数据样本并打印。
# 每个批量的特征维度显示批量大小和输入特征数。
# 同样的，批量的标签形状与`batch_size`相等。

# %%
batch_size = 10

for X, y in data_iter(batch_size, features, labels):
    print(X, '\n', y)
    # break
# Out:
# tensor([[-0.2604, -1.4508],
#         [-1.1171,  0.7284],
#         [-0.0612, -0.7788],
#         [-0.1212, -0.3786],
#         [ 0.0953, -1.4594],
#         [ 0.1993, -0.4502],
#         [ 0.3979,  2.0098],
#         [-0.4249, -1.7705],
#         [-1.6764, -1.3064],
#         [ 0.3166, -1.4752]])
#  tensor([[ 8.6117],
#         [-0.5091],
#         [ 6.7132],
#         [ 5.2627],
#         [ 9.3332],
#         [ 6.1171],
#         [-1.8441],
#         [ 9.3785],
#         [ 5.2803],
#         [ 9.8420]])
# tensor([[-1.0479,  0.4054],
#         [ 0.9871, -0.5504],
#         [-0.3798, -1.2598],
#         [ 0.2946,  1.3434],
#         [-1.6316, -2.4328],
#         [ 0.5806,  1.1756],
#         [ 0.1516,  1.4908],
#         [-1.0357,  1.9016],
#         [-3.4771, -1.3483],
#         [ 0.7771, -0.8861]])
#  tensor([[ 0.7379],
#         [ 8.0499],
#         [ 7.7413],
#         [ 0.2242],
#         [ 9.2104],
#         [ 1.3482],
#         [-0.5501],
#         [-4.3436],
#         [ 1.8333],
#         [ 8.7538]])
# tensor([[-1.8675e+00, -5.7622e-01],
#         [-2.4402e-01, -2.4746e-03],
#         [ 7.6837e-01, -1.5216e+00],
#         [-2.0506e-01, -8.4915e-01],
#         [ 4.4327e-01, -1.9056e+00],
#         [ 2.6169e+00, -6.7811e-01],
#         [-5.5219e-01, -1.7909e+00],
#         [ 6.0856e-02,  1.3065e+00],
#         [ 4.1355e-01,  2.9164e-01],
#         [ 1.6113e+00,  1.0581e+00]])
#  tensor([[ 2.4248],
#         [ 3.7073],
#         [10.9156],
#         [ 6.6869],
#         [11.5464],
#         [11.7368],
#         [ 9.1828],
#         [-0.1155],
#         [ 4.0484],
#         [ 3.8225]])
# tensor([[ 9.7461e-01,  1.0335e+00],
#         [ 1.0820e+00, -1.4461e+00],
#         [ 7.2379e-01,  2.9377e-01],
#         [ 1.3567e+00,  1.7157e+00],
#         [ 1.7837e+00,  1.3514e+00],
#         [ 2.5080e-01, -3.2139e-01],
#         [-3.1637e-04,  4.6770e-01],
#         [ 8.8698e-01, -5.3561e-01],
#         [ 3.3893e-01,  7.3959e-01],
#         [ 8.3770e-01,  1.7573e-01]])
#  tensor([[ 2.6441],
#         [11.2895],
#         [ 4.6537],
#         [ 1.0828],
#         [ 3.1713],
#         [ 5.7785],
#         [ 2.6107],
#         [ 7.8161],
#         [ 2.3536],
#         [ 5.2769]])
# tensor([[ 0.2174, -0.3049],
#         [-0.0533, -0.7285],
#         [ 0.3180,  1.8703],
#         [-1.4942, -1.5104],
#         [-0.3288, -0.2085],
#         [-0.4825,  0.9993],
#         [-1.1177, -0.1863],
#         [ 0.7679, -1.0043],
#         [-0.3072,  0.8905],
#         [ 1.6366,  1.5023]])
#  tensor([[ 5.6707],
#         [ 6.5676],
#         [-1.5170],
#         [ 6.3388],
#         [ 4.2573],
#         [-0.1711],
#         [ 2.5892],
#         [ 9.1746],
#         [ 0.5640],
#         [ 2.3565]])
# tensor([[-0.8342,  0.6530],
#         [ 0.2956,  2.5924],
#         [ 0.9260,  0.7307],
#         [ 0.1091, -0.7778],
#         [-0.5805,  0.1261],
#         [ 0.7843,  1.2077],
#         [-0.3398,  1.8782],
#         [-1.1591, -2.3075],
#         [ 1.1709,  0.2983],
#         [ 0.1343,  0.0700]])
#  tensor([[ 0.3125],
#         [-4.0163],
#         [ 3.5555],
#         [ 7.0699],
#         [ 2.6195],
#         [ 1.6466],
#         [-2.8782],
#         [ 9.7259],
#         [ 5.5277],
#         [ 4.2328]])
# tensor([[ 0.6846,  0.3714],
#         [-0.3195,  0.1178],
#         [ 1.9007, -0.1790],
#         [-1.6311, -0.4644],
#         [-0.1114,  0.1314],
#         [ 0.9146,  2.5077],
#         [ 0.9715,  0.5008],
#         [ 0.3913, -1.5651],
#         [ 0.6096,  0.8848],
#         [-0.3239, -0.9778]])
#  tensor([[ 4.3097],
#         [ 3.1616],
#         [ 8.6129],
#         [ 2.5186],
#         [ 3.5400],
#         [-2.4983],
#         [ 4.4519],
#         [10.2997],
#         [ 2.4198],
#         [ 6.8911]])
# tensor([[-0.5102, -0.1949],
#         [-0.3067, -0.7618],
#         [-0.9021,  0.4063],
#         [ 0.9490,  1.6462],
#         [ 1.1173, -0.9334],
#         [ 0.7317,  0.5199],
#         [ 0.0424, -2.1316],
#         [ 0.2756, -0.6104],
#         [ 0.5495, -0.6766],
#         [ 0.7786,  0.0882]])
#  tensor([[ 3.8207],
#         [ 6.1645],
#         [ 1.0080],
#         [ 0.5032],
#         [ 9.6021],
#         [ 3.8952],
#         [11.5499],
#         [ 6.8331],
#         [ 7.5807],
#         [ 5.4553]])
# tensor([[ 2.4688, -1.2886],
#         [-0.4753, -0.3293],
#         [-0.4814,  1.7813],
#         [ 0.5138, -0.9960],
#         [ 2.0850,  0.7062],
#         [ 0.1619,  1.4197],
#         [ 0.5285,  0.0298],
#         [ 1.0812,  0.4456],
#         [ 0.1028, -1.6999],
#         [ 0.4503,  1.6352]])
#  tensor([[13.5341],
#         [ 4.3771],
#         [-2.8079],
#         [ 8.6149],
#         [ 5.9701],
#         [-0.3107],
#         [ 5.1483],
#         [ 4.8370],
#         [10.1723],
#         [-0.4674]])
# tensor([[ 0.0564,  0.6999],
#         [ 0.5367, -1.1386],
#         [ 2.0747, -0.5937],
#         [-0.3160, -1.7907],
#         [ 1.6911,  0.8033],
#         [-0.1158, -0.5398],
#         [ 0.7020, -1.3501],
#         [ 2.0829, -1.1447],
#         [ 0.9641, -0.9519],
#         [ 0.2869,  1.1835]])
#  tensor([[ 1.9166],
#         [ 9.1370],
#         [10.3726],
#         [ 9.6440],
#         [ 4.8399],
#         [ 5.8091],
#         [10.2112],
#         [12.2575],
#         [ 9.3756],
#         [ 0.7621]])
# tensor([[ 1.4586, -2.1600],
#         [-0.8974,  2.4110],
#         [ 0.9440,  0.0812],
#         [-1.7103, -0.6534],
#         [ 0.4067,  0.1401],
#         [ 0.7249, -0.2345],
#         [ 1.3793, -0.1917],
#         [-1.0945, -1.0401],
#         [ 0.1257, -1.2379],
#         [ 0.0212,  0.5408]])
#  tensor([[14.4690],
#         [-5.7877],
#         [ 5.8131],
#         [ 3.0071],
#         [ 4.5285],
#         [ 6.4602],
#         [ 7.6045],
#         [ 5.5430],
#         [ 8.6543],
#         [ 2.4114]])
# tensor([[-0.1212, -0.8481],
#         [ 1.3950,  0.0332],
#         [-1.0724, -1.8539],
#         [-0.3607,  0.6963],
#         [-0.2223, -0.0431],
#         [-0.3315, -1.0513],
#         [-0.3335, -1.0187],
#         [ 0.2630, -1.0645],
#         [-1.1754,  1.6231],
#         [ 1.3218, -1.0882]])
#  tensor([[ 6.8512],
#         [ 6.8703],
#         [ 8.3491],
#         [ 1.1266],
#         [ 3.8987],
#         [ 7.1292],
#         [ 7.0155],
#         [ 8.3423],
#         [-3.6814],
#         [10.5613]])
# tensor([[ 0.2899, -0.4603],
#         [-0.0804,  0.5785],
#         [-1.1245,  0.4112],
#         [-0.8431,  0.8167],
#         [-0.9696,  0.3161],
#         [-0.8135,  0.1790],
#         [-0.8934, -1.4917],
#         [ 0.0421, -0.7248],
#         [ 0.2951,  1.2102],
#         [-0.4788, -0.1134]])
#  tensor([[ 6.3495],
#         [ 2.0766],
#         [ 0.5655],
#         [-0.2713],
#         [ 1.1838],
#         [ 1.9769],
#         [ 7.5007],
#         [ 6.7412],
#         [ 0.6745],
#         [ 3.6330]])
# tensor([[ 1.2505, -0.2553],
#         [ 0.9365, -0.6147],
#         [ 0.6971, -0.4575],
#         [ 0.0530,  0.4370],
#         [ 0.3866,  0.4164],
#         [ 0.8654, -0.8499],
#         [-0.5119,  0.4316],
#         [ 0.6804,  0.9384],
#         [-0.4829, -0.6426],
#         [-0.7188, -0.6384]])
#  tensor([[7.5626],
#         [8.1632],
#         [7.1547],
#         [2.8257],
#         [3.5661],
#         [8.8215],
#         [1.7197],
#         [2.3776],
#         [5.4199],
#         [4.9133]])
# tensor([[ 0.8533, -0.0873],
#         [ 0.7062,  1.1480],
#         [ 0.7227, -0.1302],
#         [ 0.2356, -0.8742],
#         [-1.3398, -0.4375],
#         [ 0.2024,  0.4895],
#         [-0.6006,  1.3186],
#         [ 1.3208,  0.2452],
#         [-0.7930, -0.8031],
#         [ 0.2941,  0.4422]])
#  tensor([[ 6.2124],
#         [ 1.6965],
#         [ 6.0937],
#         [ 7.6405],
#         [ 3.0222],
#         [ 2.9660],
#         [-1.4823],
#         [ 6.0174],
#         [ 5.3599],
#         [ 3.2725]])
# tensor([[ 0.1679, -0.0034],
#         [-0.1789, -1.1464],
#         [-0.0686,  0.5856],
#         [ 1.1608,  0.7559],
#         [-1.6021,  0.1018],
#         [-0.5094,  0.7309],
#         [ 0.2522, -0.4831],
#         [-0.4114, -1.0982],
#         [-2.7083, -0.3337],
#         [ 1.1806,  1.3442]])
#  tensor([[ 4.5465],
#         [ 7.7492],
#         [ 2.0593],
#         [ 3.9388],
#         [ 0.6319],
#         [ 0.6780],
#         [ 6.3373],
#         [ 7.1078],
#         [-0.0766],
#         [ 1.9910]])
# tensor([[ 0.3790, -1.4147],
#         [ 0.4568, -1.4204],
#         [-0.1050, -0.7135],
#         [-0.4488,  2.2010],
#         [-1.2406,  0.1088],
#         [ 0.9907, -0.9983],
#         [ 0.7424, -1.1146],
#         [-0.9583, -0.2923],
#         [ 0.9827, -0.1333],
#         [ 1.3209,  0.3280]])
#  tensor([[ 9.7600],
#         [ 9.9397],
#         [ 6.4149],
#         [-4.1587],
#         [ 1.3346],
#         [ 9.5881],
#         [ 9.4738],
#         [ 3.2775],
#         [ 6.6080],
#         [ 5.7185]])
# tensor([[ 0.1647, -0.1953],
#         [-0.3994,  0.0974],
#         [ 0.6909, -2.0168],
#         [-0.1197, -1.8353],
#         [ 0.3131,  2.3192],
#         [ 0.1309,  2.4856],
#         [-0.4514,  0.5939],
#         [-1.3522,  0.0150],
#         [ 0.3830,  0.1267],
#         [-0.6502, -1.8040]])
#  tensor([[ 5.2025],
#         [ 3.0717],
#         [12.4292],
#         [10.1991],
#         [-3.0585],
#         [-3.9901],
#         [ 1.2642],
#         [ 1.4299],
#         [ 4.5187],
#         [ 9.0264]])
# tensor([[ 0.0099,  0.2632],
#         [ 0.1755,  2.2264],
#         [-0.2192, -0.7371],
#         [-0.1829,  0.4835],
#         [ 0.7179,  0.6764],
#         [ 0.1919,  1.0152],
#         [ 1.3747,  0.7804],
#         [ 0.6239, -2.0698],
#         [-0.5348,  0.0934],
#         [ 1.1353, -0.0437]])
#  tensor([[ 3.2994],
#         [-3.0187],
#         [ 6.2753],
#         [ 2.1932],
#         [ 3.3324],
#         [ 1.1484],
#         [ 4.3006],
#         [12.4820],
#         [ 2.8340],
#         [ 6.6212]])
# tensor([[ 0.7244, -0.4347],
#         [-1.5982,  0.1174],
#         [-0.6292, -0.7962],
#         [-0.6652,  0.8439],
#         [ 0.8262,  0.8432],
#         [ 1.6291,  0.1020],
#         [-0.3479,  0.0333],
#         [ 1.1203,  0.2936],
#         [-0.4931, -1.0088],
#         [-0.2070,  1.0026]])
#  tensor([[ 7.1455],
#         [ 0.6095],
#         [ 5.6326],
#         [-0.0100],
#         [ 2.9923],
#         [ 7.1111],
#         [ 3.3883],
#         [ 5.4384],
#         [ 6.6521],
#         [ 0.3690]])
# tensor([[ 1.3241,  0.2967],
#         [-0.2185, -0.7617],
#         [-0.1648, -0.2236],
#         [ 0.4833,  0.2981],
#         [-0.1582,  0.0407],
#         [ 1.5657, -1.8195],
#         [-0.3457,  0.3382],
#         [-0.6031, -0.0105],
#         [-0.6413,  0.6626],
#         [-1.9578,  0.0692]])
#  tensor([[ 5.8523],
#         [ 6.3422],
#         [ 4.6247],
#         [ 4.1377],
#         [ 3.7526],
#         [13.5161],
#         [ 2.3555],
#         [ 3.0187],
#         [ 0.6506],
#         [ 0.0447]])
# tensor([[-0.7201, -1.8164],
#         [-0.8498, -2.0365],
#         [-0.1335,  1.3969],
#         [-0.7903,  0.7834],
#         [ 0.1983, -0.9181],
#         [-0.9307,  0.9396],
#         [ 0.6124,  0.2210],
#         [-1.3802,  0.1073],
#         [ 0.0558,  2.0698],
#         [ 0.8809, -0.5228]])
#  tensor([[ 8.9489],
#         [ 9.4400],
#         [-0.8207],
#         [-0.0577],
#         [ 7.7000],
#         [-0.8541],
#         [ 4.6654],
#         [ 1.0869],
#         [-2.7225],
#         [ 7.7197]])
# tensor([[ 0.5991, -0.6940],
#         [ 1.1573,  0.3623],
#         [ 2.0115, -0.2371],
#         [-0.9687, -1.1088],
#         [-1.4925,  2.6117],
#         [-0.8608,  0.6140],
#         [-1.5874, -0.3391],
#         [ 0.4251, -0.2154],
#         [-0.4132, -1.1371],
#         [-0.9921, -2.2966]])
#  tensor([[ 7.7572],
#         [ 5.2918],
#         [ 9.0344],
#         [ 6.0202],
#         [-7.6657],
#         [ 0.3945],
#         [ 2.1782],
#         [ 5.7769],
#         [ 7.2513],
#         [10.0271]])
# tensor([[ 6.2761e-01, -1.1600e+00],
#         [ 3.2783e-02, -1.9768e-01],
#         [-1.0373e-04, -2.9593e-01],
#         [-7.7653e-01, -9.5709e-01],
#         [-3.1211e-01,  7.1684e-01],
#         [ 3.6572e-03,  5.1127e-01],
#         [ 4.8992e-01, -1.4372e+00],
#         [ 2.4691e-02,  4.6549e-01],
#         [-1.2474e+00,  7.5803e-01],
#         [ 1.5795e-01, -2.5718e-01]])
#  tensor([[ 9.4022],
#         [ 4.9481],
#         [ 5.2139],
#         [ 5.9119],
#         [ 1.1341],
#         [ 2.4698],
#         [10.0794],
#         [ 2.6667],
#         [-0.8776],
#         [ 5.3833]])
# tensor([[-0.0333, -0.8568],
#         [-0.3777, -0.7181],
#         [ 0.2181,  0.3347],
#         [ 1.4350, -1.0151],
#         [ 0.4423, -0.3002],
#         [ 0.5156, -1.5342],
#         [ 0.9529, -0.2031],
#         [-0.5752,  0.0808],
#         [-1.6891,  0.5163],
#         [ 0.7904, -1.2916]])
#  tensor([[ 7.0319],
#         [ 5.8918],
#         [ 3.4941],
#         [10.5066],
#         [ 6.1059],
#         [10.4571],
#         [ 6.7902],
#         [ 2.7857],
#         [-0.9323],
#         [10.1865]])
# tensor([[-1.9529, -0.1335],
#         [-0.4525, -0.6618],
#         [ 0.4723, -1.0587],
#         [ 0.8921,  2.5365],
#         [-0.2389, -0.1599],
#         [-1.1875, -0.0186],
#         [-0.3797,  0.8472],
#         [-0.9964,  0.7906],
#         [-0.4365, -1.2607],
#         [ 0.3679,  0.3754]])
#  tensor([[ 0.7549],
#         [ 5.5468],
#         [ 8.7456],
#         [-2.6520],
#         [ 4.2606],
#         [ 1.8884],
#         [ 0.5666],
#         [-0.4690],
#         [ 7.6048],
#         [ 3.6432]])
# tensor([[-0.1474, -0.7001],
#         [-1.0236,  0.4836],
#         [-1.2765, -1.8824],
#         [ 1.4171,  0.2274],
#         [ 0.8178, -0.5630],
#         [-0.8361,  0.6170],
#         [ 0.3023, -0.2076],
#         [-1.3209, -1.2857],
#         [ 0.0769,  0.0691],
#         [ 0.9364,  0.9567]])
#  tensor([[6.3053],
#         [0.5027],
#         [8.0515],
#         [6.2646],
#         [7.7521],
#         [0.4378],
#         [5.5118],
#         [5.9383],
#         [4.1327],
#         [2.8342]])
# tensor([[-0.7554, -0.8578],
#         [ 1.2863,  0.0830],
#         [-0.5714, -1.8187],
#         [ 0.7543, -1.4827],
#         [-0.0030, -0.4066],
#         [-2.0368, -0.8001],
#         [ 0.0653,  0.1024],
#         [ 0.5145, -0.3401],
#         [ 0.4073, -1.7974],
#         [ 0.6295,  0.7520]])
#  tensor([[ 5.6038],
#         [ 6.4848],
#         [ 9.2436],
#         [10.7426],
#         [ 5.5741],
#         [ 2.8559],
#         [ 3.9688],
#         [ 6.3969],
#         [11.1481],
#         [ 2.8919]])
# tensor([[-0.8455,  0.3316],
#         [ 0.5840,  0.2224],
#         [ 1.3928,  0.2260],
#         [ 0.2356, -1.8615],
#         [-0.6269, -1.3107],
#         [ 0.9726, -1.2271],
#         [ 2.5403,  0.6241],
#         [ 1.2049, -0.1249],
#         [ 0.5122, -0.7994],
#         [ 1.7441,  1.2823]])
#  tensor([[ 1.3751],
#         [ 4.6251],
#         [ 6.2228],
#         [10.9945],
#         [ 7.4052],
#         [10.3091],
#         [ 7.1808],
#         [ 7.0349],
#         [ 7.9432],
#         [ 3.3290]])
# tensor([[ 0.8076, -0.8684],
#         [-1.2045,  0.3392],
#         [ 0.7241,  0.2629],
#         [-0.2650, -1.0492],
#         [ 0.5903, -2.1365],
#         [ 0.1671,  1.3952],
#         [ 0.1505,  0.4830],
#         [ 0.1635,  0.4159],
#         [-0.9162, -1.9993],
#         [ 0.9324, -1.7592]])
#  tensor([[ 8.7599],
#         [ 0.6405],
#         [ 4.7621],
#         [ 7.2403],
#         [12.6774],
#         [-0.2162],
#         [ 2.8708],
#         [ 3.1154],
#         [ 9.1753],
#         [12.0488]])
# tensor([[-2.0455,  1.2644],
#         [-0.6395, -0.6564],
#         [-0.1914, -0.8140],
#         [-1.1487,  0.8679],
#         [-1.5448,  0.3923],
#         [ 0.5139, -0.9645],
#         [-0.0418,  0.8253],
#         [ 0.3988, -0.2374],
#         [-0.7538,  0.2998],
#         [-1.3710,  0.4665]])
#  tensor([[-4.1763],
#         [ 5.1488],
#         [ 6.5937],
#         [-1.0358],
#         [-0.2381],
#         [ 8.5080],
#         [ 1.3054],
#         [ 5.7877],
#         [ 1.6806],
#         [-0.1039]])
# tensor([[-0.3110,  0.2800],
#         [-1.3102, -2.8807],
#         [-0.5123, -1.2496],
#         [-0.9437, -0.7018],
#         [-0.0098, -1.1538],
#         [ 0.4831,  0.2422],
#         [ 0.0130, -0.5910],
#         [-0.0647,  0.2550],
#         [-0.7979,  0.7166],
#         [ 0.2136,  1.6333]])
#  tensor([[ 2.6321],
#         [11.3740],
#         [ 7.4361],
#         [ 4.6948],
#         [ 8.1040],
#         [ 4.3541],
#         [ 6.2192],
#         [ 3.2025],
#         [ 0.1742],
#         [-0.9229]])
# tensor([[-0.4722,  1.0072],
#         [ 0.1234,  0.6032],
#         [-1.2962, -0.3427],
#         [-0.4645,  0.6271],
#         [-0.2610,  0.0668],
#         [ 1.2793, -1.0796],
#         [-1.4013,  0.3898],
#         [-0.0640,  1.6721],
#         [ 1.2188, -1.0248],
#         [ 0.7406,  0.6672]])
#  tensor([[-0.1851],
#         [ 2.4046],
#         [ 2.7609],
#         [ 1.1331],
#         [ 3.4566],
#         [10.4271],
#         [ 0.0748],
#         [-1.5918],
#         [10.1289],
#         [ 3.4254]])
# tensor([[-1.3552,  0.8083],
#         [ 1.6672,  0.2203],
#         [ 0.1192,  0.9649],
#         [ 0.6912,  0.2663],
#         [-2.1522,  0.4305],
#         [-0.7103,  0.5117],
#         [-0.5219, -0.3244],
#         [-1.3587,  0.3842],
#         [-0.4865, -0.4439],
#         [ 1.4836,  0.4753]])
#  tensor([[-1.2436],
#         [ 6.7970],
#         [ 1.1663],
#         [ 4.6637],
#         [-1.5791],
#         [ 1.0391],
#         [ 4.2528],
#         [ 0.1852],
#         [ 4.7287],
#         [ 5.5489]])
# tensor([[ 0.6311,  0.6265],
#         [ 0.7435, -1.7627],
#         [ 1.1412, -0.2383],
#         [-1.9159,  1.0356],
#         [ 0.9530, -0.7485],
#         [ 1.4965,  0.9603],
#         [-1.4074,  0.7898],
#         [ 1.1679,  0.3622],
#         [ 0.3306,  0.1806],
#         [-0.4578, -0.4610]])
#  tensor([[ 3.3311],
#         [11.6878],
#         [ 7.2799],
#         [-3.1444],
#         [ 8.6525],
#         [ 3.9247],
#         [-1.2967],
#         [ 5.3145],
#         [ 4.2606],
#         [ 4.8496]])
# tensor([[-0.5040,  1.1150],
#         [-0.4406, -0.5049],
#         [-0.7473, -0.5603],
#         [-2.0573, -1.2979],
#         [-0.2580, -0.3457],
#         [ 0.7420,  0.1930],
#         [-0.0553, -0.7783],
#         [ 0.7453,  0.9712],
#         [-0.4729, -1.0807],
#         [ 0.3190, -0.6883]])
#  tensor([[-0.5881],
#         [ 5.0317],
#         [ 4.6079],
#         [ 4.4981],
#         [ 4.8671],
#         [ 5.0198],
#         [ 6.7218],
#         [ 2.3843],
#         [ 6.9229],
#         [ 7.1587]])
# tensor([[ 8.8431e-01,  7.3184e-01],
#         [-9.3762e-01,  5.5330e-01],
#         [ 4.3791e-01, -1.8669e-01],
#         [-8.7999e-01,  1.0162e-01],
#         [-8.1262e-01, -1.1701e-01],
#         [-1.7719e-03, -5.7918e-01],
#         [-3.8677e-01,  3.9107e-01],
#         [-5.2004e-01, -6.5403e-01],
#         [-1.9148e-01, -9.9013e-01],
#         [ 3.1853e+00, -1.9990e-01]])
#  tensor([[ 3.4893],
#         [ 0.4175],
#         [ 5.7065],
#         [ 2.1014],
#         [ 2.9924],
#         [ 6.1745],
#         [ 2.1136],
#         [ 5.3685],
#         [ 7.1817],
#         [11.2549]])
# tensor([[-1.9162e-01,  9.2659e-01],
#         [ 1.2850e+00,  2.2341e+00],
#         [ 6.0823e-01, -4.7014e-01],
#         [-3.2426e-02, -9.1494e-01],
#         [ 4.2042e-01, -1.1208e+00],
#         [-1.1357e+00, -5.9840e-01],
#         [-1.1122e+00,  8.2367e-01],
#         [ 7.2352e-01,  9.8650e-01],
#         [ 1.0704e-01, -1.3237e-03],
#         [-1.0841e+00, -7.5640e-01]])
#  tensor([[ 0.6554],
#         [-0.8263],
#         [ 7.0061],
#         [ 7.2255],
#         [ 8.8410],
#         [ 3.9604],
#         [-0.8135],
#         [ 2.2829],
#         [ 4.4251],
#         [ 4.6040]])
# tensor([[-0.1032,  0.1712],
#         [ 0.4868,  1.1891],
#         [ 0.1802,  0.0889],
#         [ 1.0737, -1.0236],
#         [ 0.0305, -1.5381],
#         [ 2.5745,  0.0177],
#         [-0.0726, -0.0874],
#         [ 0.6335, -1.8373],
#         [ 0.4609,  0.9344],
#         [-1.3096,  0.5066]])
#  tensor([[ 3.3978],
#         [ 1.1318],
#         [ 4.2582],
#         [ 9.8321],
#         [ 9.4765],
#         [ 9.2962],
#         [ 4.3531],
#         [11.7174],
#         [ 1.9488],
#         [-0.1338]])
# tensor([[-0.6653,  2.2544],
#         [-0.7029, -2.3397],
#         [-0.1078,  1.0515],
#         [ 1.4659, -0.2603],
#         [-0.4068,  1.6026],
#         [-0.1264, -1.1149],
#         [-0.0227,  0.1987],
#         [-0.8266, -1.2755],
#         [ 0.2775, -0.4483],
#         [-0.8040,  0.2381]])
#  tensor([[-4.8190],
#         [10.7408],
#         [ 0.4064],
#         [ 8.0336],
#         [-2.0538],
#         [ 7.7508],
#         [ 3.4830],
#         [ 6.8772],
#         [ 6.2847],
#         [ 1.7777]])
# tensor([[ 0.2403, -0.4084],
#         [ 0.8130, -0.2376],
#         [-0.6653,  0.6535],
#         [-2.0841,  0.3105],
#         [-0.7905,  0.4629],
#         [-0.8218, -0.8730],
#         [-0.5266, -0.9974],
#         [ 1.3777, -0.0794],
#         [-1.0754, -0.2263],
#         [-0.7185,  0.9250]])
#  tensor([[ 6.0685],
#         [ 6.6470],
#         [ 0.6509],
#         [-1.0092],
#         [ 1.0525],
#         [ 5.5104],
#         [ 6.5343],
#         [ 7.2325],
#         [ 2.8155],
#         [-0.3783]])
# tensor([[-0.7264,  0.0989],
#         [-2.4430,  0.3419],
#         [ 0.0825, -0.0192],
#         [-0.1927, -2.2522],
#         [-0.9327, -0.7583],
#         [ 2.3311,  0.0720],
#         [ 0.6607, -0.2904],
#         [ 1.1062,  0.4731],
#         [ 0.2227,  0.2470],
#         [ 0.3769, -0.5448]])
#  tensor([[ 2.4030],
#         [-1.8425],
#         [ 4.4341],
#         [11.4858],
#         [ 4.9136],
#         [ 8.6050],
#         [ 6.5108],
#         [ 4.8042],
#         [ 3.8047],
#         [ 6.8315]])
# tensor([[ 0.7774, -2.4418],
#         [ 0.2702, -1.6117],
#         [-0.4141,  0.1123],
#         [ 1.6633, -0.5408],
#         [-1.2723, -0.1053],
#         [ 1.2360,  1.3077],
#         [-0.2221,  0.1984],
#         [ 0.4201, -1.1805],
#         [ 1.0598, -1.8166],
#         [ 0.2587, -0.7053]])
#  tensor([[14.0580],
#         [10.2159],
#         [ 2.9886],
#         [ 9.3807],
#         [ 2.0015],
#         [ 2.2390],
#         [ 3.0955],
#         [ 9.0610],
#         [12.5072],
#         [ 7.1245]])
# tensor([[-0.2112,  1.5180],
#         [ 0.5311, -1.0061],
#         [-0.0146,  0.4389],
#         [-0.9096,  1.7225],
#         [-1.3551,  0.8823],
#         [-0.3349,  1.4191],
#         [ 0.3301,  2.3191],
#         [ 0.4140,  1.1700],
#         [-0.4757, -0.5459],
#         [ 0.5545, -1.5719]])
#  tensor([[-1.4004],
#         [ 8.6929],
#         [ 2.6825],
#         [-3.4639],
#         [-1.5069],
#         [-1.2807],
#         [-3.0259],
#         [ 1.0532],
#         [ 5.0964],
#         [10.6458]])
# tensor([[-1.2675e+00, -4.2051e-01],
#         [ 8.2131e-01,  1.4830e+00],
#         [-1.5267e+00,  1.2108e+00],
#         [-1.7301e-01,  7.2385e-01],
#         [-1.7685e-01, -5.0390e-02],
#         [-7.0910e-01,  3.3615e-01],
#         [ 4.6219e-01,  2.5859e+00],
#         [ 5.4561e-04,  1.0767e+00],
#         [ 3.5531e-01, -1.3395e+00],
#         [ 8.7442e-01, -5.2618e-02]])
#  tensor([[ 3.0988],
#         [ 0.8092],
#         [-2.9546],
#         [ 1.3790],
#         [ 4.0207],
#         [ 1.6360],
#         [-3.6591],
#         [ 0.5235],
#         [ 9.4602],
#         [ 6.1343]])
# tensor([[ 0.0784, -0.1906],
#         [-0.4946,  0.6593],
#         [-0.2552,  1.0655],
#         [ 0.9248, -1.2815],
#         [-1.7418, -1.3801],
#         [-0.8205, -1.1113],
#         [ 0.1005, -0.9949],
#         [-0.9477,  0.5390],
#         [-0.8516,  0.3506],
#         [-0.3564,  1.3963]])
#  tensor([[ 4.9928],
#         [ 0.9729],
#         [ 0.0649],
#         [10.4179],
#         [ 5.4045],
#         [ 6.3402],
#         [ 7.7691],
#         [ 0.4801],
#         [ 1.2951],
#         [-1.2528]])
# tensor([[-0.9899,  0.1783],
#         [ 0.8432, -0.4133],
#         [ 0.1702,  0.5330],
#         [-1.3444, -0.2374],
#         [ 0.8163,  1.1092],
#         [-0.1661, -0.9324],
#         [-2.6130, -0.4353],
#         [-0.1725,  0.3674],
#         [ 0.3130, -0.2579],
#         [-2.7975,  0.7993]])
#  tensor([[ 1.5987],
#         [ 7.2917],
#         [ 2.7247],
#         [ 2.3160],
#         [ 2.0621],
#         [ 7.0385],
#         [ 0.4593],
#         [ 2.6046],
#         [ 5.6996],
#         [-4.1113]])
# tensor([[ 0.6311, -1.0224],
#         [-0.0261,  0.4654],
#         [ 0.6305,  0.1514],
#         [ 1.5835, -0.9969],
#         [ 0.2289,  0.4329],
#         [ 0.1751, -0.8793],
#         [ 0.8468,  1.3108],
#         [-0.6241,  1.8688],
#         [-0.2346,  0.7200],
#         [-1.9240,  2.5261]])
#  tensor([[ 8.9349],
#         [ 2.5583],
#         [ 4.9447],
#         [10.7686],
#         [ 3.1722],
#         [ 7.5462],
#         [ 1.4308],
#         [-3.4113],
#         [ 1.2762],
#         [-8.2441]])
# tensor([[ 0.0365, -0.6173],
#         [-1.8747, -0.5078],
#         [-1.1498, -0.0239],
#         [-0.7224, -0.7671],
#         [ 0.6057, -0.1408],
#         [-0.5332,  0.1478],
#         [ 0.5020,  2.3348],
#         [-2.1719, -1.9331],
#         [-1.4000, -0.1719],
#         [-1.5797,  2.3481]])
#  tensor([[ 6.3812],
#         [ 2.1840],
#         [ 1.9725],
#         [ 5.3752],
#         [ 5.8919],
#         [ 2.6268],
#         [-2.7442],
#         [ 6.4375],
#         [ 1.9808],
#         [-6.9386]])
# tensor([[ 0.7900,  1.0162],
#         [ 0.5946,  1.1027],
#         [-0.7149,  0.2133],
#         [-0.0270,  1.4050],
#         [ 0.5423, -1.3693],
#         [-0.5428, -0.1254],
#         [ 0.8649, -0.2580],
#         [-0.5466, -0.5079],
#         [ 0.6046, -0.6294],
#         [ 1.6267, -0.5455]])
#  tensor([[ 2.3432],
#         [ 1.6512],
#         [ 2.0305],
#         [-0.6330],
#         [ 9.9488],
#         [ 3.5380],
#         [ 6.8164],
#         [ 4.8554],
#         [ 7.5410],
#         [ 9.3336]])
# tensor([[ 0.0898,  0.4646],
#         [-1.0775,  1.2436],
#         [-0.9047,  1.0282],
#         [-0.2617,  0.3515],
#         [ 0.2546,  0.9463],
#         [ 0.5986, -0.1401],
#         [-0.7912, -0.1868],
#         [-0.7527,  1.0431],
#         [ 0.7035,  0.4969],
#         [ 1.8841, -0.8710]])
#  tensor([[ 2.8067],
#         [-2.1983],
#         [-1.1005],
#         [ 2.4813],
#         [ 1.4955],
#         [ 5.8938],
#         [ 3.2683],
#         [-0.8693],
#         [ 3.9158],
#         [10.9117]])
# tensor([[-0.2255,  0.4112],
#         [ 2.6652, -0.3814],
#         [ 0.8010, -0.0833],
#         [ 1.0398, -0.5073],
#         [-0.3902,  0.6712],
#         [ 1.3052, -0.1105],
#         [-0.1389, -0.8721],
#         [-1.1752,  0.7690],
#         [-0.1650, -0.3223],
#         [ 0.0915,  0.1472]])
#  tensor([[ 2.3659],
#         [10.8220],
#         [ 6.0788],
#         [ 8.0105],
#         [ 1.1356],
#         [ 7.1985],
#         [ 6.8915],
#         [-0.7772],
#         [ 4.9683],
#         [ 3.8818]])
# tensor([[ 0.6929, -0.0718],
#         [ 0.1896, -2.2062],
#         [ 1.1040, -1.2271],
#         [-1.0975,  0.6724],
#         [ 0.1116, -0.3772],
#         [ 0.8861, -0.3378],
#         [ 0.5290, -1.2834],
#         [-0.2984, -0.4146],
#         [-2.0440,  0.3897],
#         [-1.4595, -0.1049]])
#  tensor([[ 5.8388],
#         [12.0826],
#         [10.5824],
#         [-0.2788],
#         [ 5.7022],
#         [ 7.1197],
#         [ 9.6229],
#         [ 5.0155],
#         [-1.2330],
#         [ 1.6297]])
# tensor([[-0.1844,  0.0296],
#         [ 0.3973,  0.8069],
#         [ 1.5579, -0.7785],
#         [ 2.0339, -1.4307],
#         [ 0.2740,  0.9952],
#         [ 0.9886, -0.8970],
#         [ 1.5721, -0.9034],
#         [ 1.0790,  0.5530],
#         [ 0.3062,  0.5632],
#         [ 0.4156,  0.1783]])
#  tensor([[ 3.7292],
#         [ 2.2606],
#         [ 9.9596],
#         [13.1143],
#         [ 1.3497],
#         [ 9.2317],
#         [10.4206],
#         [ 4.4816],
#         [ 2.8970],
#         [ 4.4231]])
# tensor([[-2.0980, -0.1083],
#         [-0.1113, -1.3761],
#         [-0.9865, -0.8178],
#         [ 0.2065,  0.7059],
#         [-0.4078, -0.3614],
#         [ 0.6008, -0.7968],
#         [ 1.0067,  0.7459],
#         [-1.0474, -0.9653],
#         [ 0.9501,  1.2880],
#         [-0.1455, -0.5738]])
#  tensor([[0.3717],
#         [8.6312],
#         [4.9972],
#         [2.2168],
#         [4.5960],
#         [8.0923],
#         [3.6900],
#         [5.3996],
#         [1.7360],
#         [5.8500]])
# tensor([[ 0.0961, -1.9444],
#         [ 2.8171, -0.0461],
#         [ 0.6892,  0.5196],
#         [-2.5930, -0.0410],
#         [-1.4081,  1.5376],
#         [-0.7504,  1.5679],
#         [-1.6522, -0.6923],
#         [ 0.1836, -1.4857],
#         [ 1.6816, -1.9594],
#         [ 0.0635, -0.6719]])
#  tensor([[10.9737],
#         [10.0061],
#         [ 3.7904],
#         [-0.8392],
#         [-3.8573],
#         [-2.6434],
#         [ 3.2505],
#         [ 9.6245],
#         [14.2389],
#         [ 6.6164]])
# tensor([[-0.1559, -1.6426],
#         [-0.2424,  0.1634],
#         [-1.4125, -0.6729],
#         [-0.8138, -0.1581],
#         [-1.6069, -0.1248],
#         [-0.1082,  0.8748],
#         [-0.4132,  0.5429],
#         [ 0.5744, -0.3083],
#         [-1.3161,  0.6730],
#         [-0.5612, -0.8493]])
#  tensor([[ 9.4831],
#         [ 3.1568],
#         [ 3.6483],
#         [ 3.1104],
#         [ 1.4204],
#         [ 1.0129],
#         [ 1.5353],
#         [ 6.4199],
#         [-0.7278],
#         [ 5.9827]])
# tensor([[-1.1402, -0.6191],
#         [-0.2202, -2.8372],
#         [-2.2445, -0.5429],
#         [-0.1705,  0.4428],
#         [ 1.0421, -0.0423],
#         [-0.8258,  0.7338],
#         [ 1.5171,  0.6568],
#         [ 0.9219,  0.2754],
#         [ 1.9091,  0.0348],
#         [-0.2395, -0.6408]])
#  tensor([[ 4.0366],
#         [13.4127],
#         [ 1.5637],
#         [ 2.3399],
#         [ 6.4391],
#         [ 0.0620],
#         [ 4.9869],
#         [ 5.1042],
#         [ 7.9002],
#         [ 5.9059]])
# tensor([[-0.8842, -0.4470],
#         [ 1.8896, -0.4850],
#         [ 0.9657, -0.0947],
#         [-1.7914, -0.6381],
#         [ 0.4573, -0.3263],
#         [-0.1091,  0.7839],
#         [-0.1909,  1.3751],
#         [-1.0847,  0.4688],
#         [ 0.9825,  0.3672],
#         [ 1.0021,  0.1970]])
#  tensor([[ 3.9476],
#         [ 9.6085],
#         [ 6.4797],
#         [ 2.7739],
#         [ 6.2340],
#         [ 1.3263],
#         [-0.8475],
#         [ 0.4414],
#         [ 4.9244],
#         [ 5.5274]])
# tensor([[-1.1022, -0.2315],
#         [ 1.8356, -0.9317],
#         [ 0.2610,  0.3494],
#         [ 1.2222,  2.8498],
#         [-0.4055, -0.1867],
#         [ 0.5314, -0.1137],
#         [-0.7945, -0.0405],
#         [ 0.1365, -2.0042],
#         [ 0.1532, -2.1830],
#         [-0.1830,  0.9072]])
#  tensor([[ 2.7935],
#         [11.0343],
#         [ 3.5382],
#         [-3.0576],
#         [ 4.0168],
#         [ 5.6524],
#         [ 2.7560],
#         [11.2893],
#         [11.9310],
#         [ 0.7580]])
# tensor([[ 1.3894, -0.9782],
#         [ 0.6713,  0.5137],
#         [ 0.8341,  0.8233],
#         [ 0.2042, -0.3098],
#         [ 0.2481,  1.2965],
#         [-0.7696,  0.1575],
#         [ 0.4652, -0.2458],
#         [-1.3649, -0.6920],
#         [ 0.1480, -1.1270],
#         [ 0.7042,  1.0037]])
#  tensor([[10.2979],
#         [ 3.8056],
#         [ 3.0687],
#         [ 5.6803],
#         [ 0.2797],
#         [ 2.1273],
#         [ 5.9497],
#         [ 3.8117],
#         [ 8.3431],
#         [ 2.2090]])
# tensor([[-0.3937, -0.2912],
#         [ 0.3254, -0.4529],
#         [-1.0388,  0.8812],
#         [ 0.3814, -0.5961],
#         [-0.6650,  0.0947],
#         [-0.4163,  0.7539],
#         [-0.3088, -0.6894],
#         [-0.5031,  0.5699],
#         [ 1.4322, -0.5046],
#         [-1.4564, -1.3511]])
#  tensor([[ 4.4151],
#         [ 6.3880],
#         [-0.8837],
#         [ 6.9631],
#         [ 2.5529],
#         [ 0.8026],
#         [ 5.9151],
#         [ 1.2626],
#         [ 8.7757],
#         [ 5.8923]])
# tensor([[ 0.4076, -0.2783],
#         [-0.3353, -0.5232],
#         [ 0.0965,  0.5621],
#         [ 1.2940, -0.0555],
#         [ 0.2977, -0.7695],
#         [ 0.4345, -1.5956],
#         [-0.6391, -0.4606],
#         [-1.3561, -1.7856],
#         [-1.7101,  1.5428],
#         [ 1.0204, -0.3244]])
#  tensor([[ 5.9652],
#         [ 5.3125],
#         [ 2.4846],
#         [ 6.9814],
#         [ 7.4389],
#         [10.4946],
#         [ 4.4979],
#         [ 7.5498],
#         [-4.4648],
#         [ 7.3555]])
# tensor([[-0.7473,  0.9585],
#         [ 1.0680,  0.1008],
#         [-0.2229, -0.4725],
#         [ 0.1098,  0.0501],
#         [-0.5588, -0.8823],
#         [-0.5949,  0.2848],
#         [ 0.4561, -0.3147],
#         [ 1.6971,  0.0864],
#         [ 2.0616, -0.7848],
#         [-1.0355, -1.5230]])
#  tensor([[-0.5427],
#         [ 5.9945],
#         [ 5.3609],
#         [ 4.2329],
#         [ 6.0778],
#         [ 2.0404],
#         [ 6.1919],
#         [ 7.2941],
#         [10.9739],
#         [ 7.2996]])
# tensor([[-0.5184,  0.4054],
#         [ 0.0826,  0.6300],
#         [ 0.3057,  1.7827],
#         [-1.8465, -0.5217],
#         [ 0.5130, -0.5283],
#         [-2.6465,  0.6241],
#         [ 1.3154,  0.0131],
#         [ 2.1056,  0.3354],
#         [-1.5362, -0.3365],
#         [-0.5417,  0.1208]])
#  tensor([[ 1.7860],
#         [ 2.2220],
#         [-1.2456],
#         [ 2.2792],
#         [ 7.0315],
#         [-3.2073],
#         [ 6.7949],
#         [ 7.2660],
#         [ 2.2630],
#         [ 2.6906]])
# tensor([[ 2.4305, -0.3599],
#         [ 0.3026,  0.4909],
#         [ 0.1826, -1.3986],
#         [ 0.7797,  0.6737],
#         [-0.4057, -1.8483],
#         [ 1.5029, -1.3676],
#         [-0.5986,  0.1606],
#         [ 0.2796,  1.4416],
#         [-0.4601, -0.4755],
#         [-1.8778,  0.9194]])
#  tensor([[10.2996],
#         [ 3.1387],
#         [ 9.3332],
#         [ 3.4640],
#         [ 9.6739],
#         [11.8681],
#         [ 2.4564],
#         [-0.1456],
#         [ 4.9044],
#         [-2.6712]])
# tensor([[-0.4925, -0.6008],
#         [ 1.2471,  1.2059],
#         [-0.1100,  0.0114],
#         [ 1.6134, -1.1285],
#         [-0.0357, -0.8350],
#         [-0.5899, -1.4360],
#         [-0.9302,  0.5068],
#         [ 0.3772,  1.4814],
#         [ 1.1755, -0.2029],
#         [ 0.5651, -1.2645]])
#  tensor([[ 5.2503],
#         [ 2.5819],
#         [ 3.9456],
#         [11.2553],
#         [ 6.9632],
#         [ 7.8871],
#         [ 0.6173],
#         [-0.1036],
#         [ 7.2508],
#         [ 9.6462]])
# tensor([[ 0.0924,  0.1252],
#         [ 0.3268,  1.0132],
#         [ 0.3189,  1.1036],
#         [ 0.0521, -0.7791],
#         [ 1.8138, -1.0594],
#         [ 0.8891,  0.4502],
#         [-0.1725,  0.7013],
#         [ 0.0995, -1.0012],
#         [-1.0588,  0.9291],
#         [ 0.7871,  0.0589]])
#  tensor([[ 3.9613],
#         [ 1.4052],
#         [ 1.0928],
#         [ 6.9531],
#         [11.4288],
#         [ 4.4378],
#         [ 1.4566],
#         [ 7.8029],
#         [-1.0826],
#         [ 5.5895]])
# tensor([[ 1.4972, -1.2132],
#         [-1.6414, -0.7186],
#         [ 0.7143,  3.4668],
#         [-0.9817, -0.7386],
#         [ 1.2140, -1.0429],
#         [ 0.5163, -0.0606],
#         [ 0.3785,  0.7770],
#         [-0.3445, -0.0181],
#         [ 1.5439, -0.8012],
#         [-0.0309, -0.8134]])
#  tensor([[11.3145],
#         [ 3.3553],
#         [-6.1484],
#         [ 4.7292],
#         [10.1863],
#         [ 5.4452],
#         [ 2.2918],
#         [ 3.5844],
#         [10.0102],
#         [ 6.9310]])
# tensor([[-0.1217,  0.7051],
#         [-0.3953,  0.3756],
#         [ 0.9619, -1.0807],
#         [-1.0910,  0.7605],
#         [ 0.2978,  0.3820],
#         [ 0.0620, -1.1658],
#         [-0.5485,  0.2567],
#         [-0.1843, -0.0082],
#         [ 1.8056,  2.0412],
#         [ 0.5836,  0.0244]])
#  tensor([[ 1.5499],
#         [ 2.1354],
#         [ 9.8015],
#         [-0.5705],
#         [ 3.4831],
#         [ 8.2951],
#         [ 2.2345],
#         [ 3.8611],
#         [ 0.8858],
#         [ 5.2759]])
# tensor([[-1.3301,  0.8571],
#         [ 0.0655, -0.6251],
#         [-2.1162, -0.5449],
#         [ 0.3256,  0.8022],
#         [-1.1878,  0.0456],
#         [-1.6269, -0.0922],
#         [-1.5731, -0.9696],
#         [-0.1934,  0.6172],
#         [ 0.6291, -0.2856],
#         [-1.6511,  1.5735]])
#  tensor([[-1.3796],
#         [ 6.4347],
#         [ 1.8111],
#         [ 2.1273],
#         [ 1.6909],
#         [ 1.2774],
#         [ 4.3644],
#         [ 1.7154],
#         [ 6.4384],
#         [-4.4602]])
# tensor([[ 1.9310, -1.5153],
#         [-1.1613, -0.8355],
#         [-0.1137,  1.4696],
#         [ 0.0744,  1.0209],
#         [ 0.5982,  1.9819],
#         [ 0.1481, -0.4522],
#         [ 0.4035,  0.8112],
#         [ 1.2099, -0.5833],
#         [ 0.3550,  0.2322],
#         [ 0.0576, -1.1323]])
#  tensor([[13.2014],
#         [ 4.7249],
#         [-1.0287],
#         [ 0.8940],
#         [-1.3548],
#         [ 6.0278],
#         [ 2.2557],
#         [ 8.5945],
#         [ 4.1407],
#         [ 8.1640]])
# tensor([[-0.5457, -1.5550],
#         [-0.4986,  1.8454],
#         [-0.0667,  1.3124],
#         [ 1.0498, -0.5629],
#         [-0.0581, -1.0382],
#         [ 1.4116, -0.5107],
#         [ 1.4275,  1.2813],
#         [ 1.0783, -0.4540],
#         [-0.0596,  0.2220],
#         [ 0.6922,  0.1536]])
#  tensor([[ 8.4023],
#         [-3.0517],
#         [-0.3904],
#         [ 8.2227],
#         [ 7.6285],
#         [ 8.7822],
#         [ 2.6991],
#         [ 7.8938],
#         [ 3.3343],
#         [ 5.0576]])
# tensor([[ 0.3381,  1.0491],
#         [-0.1557, -1.0359],
#         [ 0.8241, -1.7999],
#         [ 0.0924, -0.0945],
#         [-2.3239,  0.6034],
#         [ 0.1139, -0.3635],
#         [-0.0932, -0.3999],
#         [ 2.2964, -0.4335],
#         [-0.1816, -0.7339],
#         [-0.2883, -1.6966]])
#  tensor([[ 1.3235],
#         [ 7.4095],
#         [11.9637],
#         [ 4.7147],
#         [-2.4988],
#         [ 5.6576],
#         [ 5.3686],
#         [10.2612],
#         [ 6.3130],
#         [ 9.3952]])
# tensor([[-0.7633, -0.2590],
#         [-0.1822, -0.3250],
#         [ 1.8398,  0.5165],
#         [-1.1693,  0.3577],
#         [-0.3661, -1.1289],
#         [-1.4893,  1.2580],
#         [-0.9701,  0.5797],
#         [ 1.4025,  3.1858],
#         [-0.0173, -0.6952],
#         [-0.1863, -2.3725]])
#  tensor([[ 3.5435],
#         [ 4.9169],
#         [ 6.1249],
#         [ 0.6320],
#         [ 7.3002],
#         [-3.0652],
#         [ 0.2867],
#         [-3.8390],
#         [ 6.5456],
#         [11.8945]])
# tensor([[-1.2760,  1.0055],
#         [-0.2835,  1.4027],
#         [ 1.7700,  1.3873],
#         [ 0.2515, -0.2748],
#         [-1.6185, -1.3333],
#         [ 0.1750,  0.4644],
#         [ 0.9874,  0.3409],
#         [ 1.2670,  0.1425],
#         [-0.9542, -0.2537],
#         [-1.3202, -0.0537]])
#  tensor([[-1.7733],
#         [-1.1349],
#         [ 3.0039],
#         [ 5.6376],
#         [ 5.5016],
#         [ 2.9509],
#         [ 5.0098],
#         [ 6.2486],
#         [ 3.1491],
#         [ 1.7310]])
# tensor([[-1.3208,  0.3838],
#         [-0.6986, -0.7033],
#         [ 0.0206,  0.9036],
#         [ 0.2983, -0.4210],
#         [-1.4795, -0.1531],
#         [ 0.6044, -0.2238],
#         [-0.6932, -0.8664],
#         [-0.1867,  0.5441],
#         [ 0.8391,  1.9063],
#         [-0.7904, -0.2171]])
#  tensor([[ 0.2716],
#         [ 5.1937],
#         [ 1.1645],
#         [ 6.2306],
#         [ 1.7595],
#         [ 6.1687],
#         [ 5.7674],
#         [ 1.9703],
#         [-0.6043],
#         [ 3.3745]])
# tensor([[-0.7113,  0.1068],
#         [-0.7008, -0.2175],
#         [ 1.7681, -0.4348],
#         [ 2.3944, -1.3852],
#         [-1.4541, -0.5995],
#         [-0.5663,  0.2436],
#         [-1.6412,  0.5765],
#         [-0.0963,  0.6701],
#         [ 1.0739,  1.5611],
#         [-1.6037, -0.5136]])
#  tensor([[ 2.4103],
#         [ 3.5241],
#         [ 9.2136],
#         [13.6975],
#         [ 3.3286],
#         [ 2.2213],
#         [-1.0396],
#         [ 1.7381],
#         [ 1.0161],
#         [ 2.7266]])
# tensor([[ 0.5247,  0.6976],
#         [ 1.1926, -0.4036],
#         [-0.8424, -0.6555],
#         [-0.1594,  0.2316],
#         [ 0.4001,  0.5093],
#         [-0.6455, -0.3115],
#         [ 0.7982, -0.1208],
#         [ 0.6052, -0.6009],
#         [ 0.7846, -0.7775],
#         [ 1.6663,  0.7523]])
#  tensor([[2.8648],
#         [7.9699],
#         [4.7298],
#         [3.1003],
#         [3.2719],
#         [3.9642],
#         [6.2016],
#         [7.4580],
#         [8.4309],
#         [4.9616]])
# tensor([[ 0.6920,  0.3485],
#         [-0.0107, -0.7679],
#         [-1.1862, -0.3190],
#         [ 0.0016, -0.4843],
#         [ 0.8722,  1.4601],
#         [-0.0830,  0.6838],
#         [ 0.9040,  1.0310],
#         [ 1.5348,  1.0480],
#         [ 0.2843,  0.1665],
#         [-0.3823,  0.9812]])
#  tensor([[4.3902],
#         [6.7831],
#         [2.9186],
#         [5.8449],
#         [0.9837],
#         [1.7138],
#         [2.5028],
#         [3.7263],
#         [4.2052],
#         [0.0957]])
# tensor([[-0.3433, -0.3074],
#         [-0.7973,  0.5676],
#         [-1.4984, -1.0177],
#         [ 0.5663, -1.0225],
#         [-2.0855, -0.1312],
#         [ 1.0995,  1.2889],
#         [ 1.5094,  0.2280],
#         [ 0.9191,  0.3450],
#         [ 2.1736,  1.9065],
#         [-1.7782,  0.1578]])
#  tensor([[4.5568],
#         [0.6766],
#         [4.6629],
#         [8.8105],
#         [0.4725],
#         [2.0269],
#         [6.4387],
#         [4.8439],
#         [2.0661],
#         [0.1070]])
# tensor([[-0.1716,  0.9116],
#         [ 0.3843, -1.7013],
#         [-0.1584,  0.9806],
#         [ 0.5986,  1.7156],
#         [ 1.2816, -0.3165],
#         [ 1.5680, -0.8542],
#         [-0.9833,  0.1313],
#         [ 1.4625, -1.0526],
#         [-0.2280, -0.2448],
#         [ 2.5341,  1.0232]])
#  tensor([[ 0.7738],
#         [10.7629],
#         [ 0.5460],
#         [-0.4493],
#         [ 7.8500],
#         [10.2344],
#         [ 1.7904],
#         [10.7036],
#         [ 4.5724],
#         [ 5.7899]])
# tensor([[-1.3186,  0.7299],
#         [ 2.1107,  0.0765],
#         [ 0.2197,  0.3420],
#         [ 0.7782,  0.0531],
#         [-0.2354,  0.7132],
#         [ 0.6610,  0.0298],
#         [ 0.5925, -2.5423],
#         [ 2.1420, -1.5785],
#         [-0.8946, -0.6077],
#         [ 0.9333, -1.5671]])
#  tensor([[-0.9058],
#         [ 8.1634],
#         [ 3.4650],
#         [ 5.5643],
#         [ 1.3007],
#         [ 5.4160],
#         [14.0375],
#         [13.8576],
#         [ 4.4777],
#         [11.4004]])
# tensor([[-0.2946,  1.0289],
#         [ 1.4345, -1.0874],
#         [ 0.1551, -0.4416],
#         [-1.3050,  0.7194],
#         [-1.1119,  0.8930],
#         [ 0.8882,  0.7201],
#         [ 1.8088, -1.4338],
#         [-0.1638,  0.4719],
#         [-0.2366,  0.3217],
#         [ 0.2259,  0.6561]])
#  tensor([[ 0.1033],
#         [10.7624],
#         [ 6.0012],
#         [-0.8510],
#         [-1.0537],
#         [ 3.5437],
#         [12.7135],
#         [ 2.2671],
#         [ 2.6378],
#         [ 2.4316]])
# tensor([[-0.3526, -0.1672],
#         [-0.6416, -1.4706],
#         [-0.8995, -1.8034],
#         [-0.3900, -0.7199],
#         [ 0.4262,  0.0346],
#         [-0.8370, -0.2359],
#         [-1.4879, -0.0606],
#         [ 0.2089, -0.7931],
#         [-0.0582, -1.0145],
#         [ 1.4696,  0.1110]])
#  tensor([[4.0437],
#         [7.9213],
#         [8.5387],
#         [5.8888],
#         [4.9285],
#         [3.3321],
#         [1.4285],
#         [7.3161],
#         [7.5502],
#         [6.7632]])
# tensor([[ 0.4542,  0.6089],
#         [-1.4816, -0.2223],
#         [-1.0607,  1.9883],
#         [ 0.1892, -0.2512],
#         [-0.2298, -0.3355],
#         [ 0.9596, -0.2481],
#         [ 0.2657, -0.9060],
#         [-0.6369, -0.9162],
#         [ 0.4127, -0.7523],
#         [-0.3683,  0.3607]])
#  tensor([[ 3.0415],
#         [ 1.9915],
#         [-4.7015],
#         [ 5.4345],
#         [ 4.8923],
#         [ 6.9741],
#         [ 7.8141],
#         [ 6.0330],
#         [ 7.5855],
#         [ 2.2428]])
# tensor([[-0.0196,  0.5846],
#         [-0.7618, -0.7669],
#         [-1.6913, -0.4442],
#         [ 1.2003,  0.5711],
#         [-0.9827,  0.6048],
#         [ 1.4629, -0.6768],
#         [ 0.7744, -1.3754],
#         [ 0.5695, -0.3780],
#         [ 0.0877,  0.2587],
#         [-0.8627, -1.1303]])
#  tensor([[ 2.1732],
#         [ 5.2851],
#         [ 2.3368],
#         [ 4.6315],
#         [ 0.1824],
#         [ 9.4304],
#         [10.4087],
#         [ 6.6167],
#         [ 3.4859],
#         [ 6.3307]])
# tensor([[ 1.3542,  0.8949],
#         [ 0.9468, -0.7897],
#         [-0.6249, -0.8168],
#         [ 0.6994,  0.0467],
#         [ 0.5530,  1.2047],
#         [ 0.9158, -0.0710],
#         [-0.9151, -0.9466],
#         [-1.7511,  0.6784],
#         [ 0.9259, -1.2851],
#         [-2.3584, -0.2996]])
#  tensor([[ 3.8669],
#         [ 8.7887],
#         [ 5.7358],
#         [ 5.4650],
#         [ 1.2152],
#         [ 6.2713],
#         [ 5.5938],
#         [-1.5857],
#         [10.4253],
#         [ 0.4822]])
# tensor([[-0.9073,  1.3315],
#         [ 0.2397, -0.5507],
#         [-0.2008,  0.0661],
#         [-0.2213,  0.2281],
#         [-2.0694,  0.6397],
#         [ 0.6529,  0.5145],
#         [ 1.1020,  0.2202],
#         [ 2.1934,  0.6706],
#         [ 1.1640,  0.8452],
#         [-0.5395, -0.9554]])
#  tensor([[-2.1396],
#         [ 6.5422],
#         [ 3.5727],
#         [ 2.9951],
#         [-2.1300],
#         [ 3.7624],
#         [ 5.6529],
#         [ 6.3108],
#         [ 3.6422],
#         [ 6.3765]])
# tensor([[-0.1473,  0.0694],
#         [ 0.0435,  0.1486],
#         [ 1.8923, -0.6428],
#         [-1.1529,  0.7414],
#         [ 0.6560,  0.0046],
#         [-0.5204, -0.1545],
#         [ 0.5546,  0.7150],
#         [-1.8401,  0.6675],
#         [-0.2026,  0.8248],
#         [-0.7722, -0.1739]])
#  tensor([[ 3.6605],
#         [ 3.7960],
#         [10.1705],
#         [-0.6376],
#         [ 5.4915],
#         [ 3.6894],
#         [ 2.8843],
#         [-1.7441],
#         [ 0.9796],
#         [ 3.2443]])
# tensor([[ 0.1553, -1.0294],
#         [ 0.0615,  0.1052],
#         [-0.5022, -1.0219],
#         [-0.7420,  0.6343],
#         [-1.0868, -0.0706],
#         [-1.6428,  0.7855],
#         [-0.7085, -1.8981],
#         [ 0.0921,  1.8689],
#         [ 0.7598,  0.4509],
#         [-0.8130, -1.3507]])
#  tensor([[ 8.0208],
#         [ 3.9694],
#         [ 6.6721],
#         [ 0.5661],
#         [ 2.2653],
#         [-1.7588],
#         [ 9.2376],
#         [-1.9673],
#         [ 4.1989],
#         [ 7.1450]])
# tensor([[ 1.6668, -0.5746],
#         [ 0.4625,  1.7580],
#         [ 2.7795,  1.4676],
#         [ 0.9551, -1.6351],
#         [ 0.2933,  3.1634],
#         [ 1.2238,  1.3521],
#         [-0.7163, -1.7632],
#         [ 0.6417,  0.2600],
#         [ 0.3430, -0.7872],
#         [ 0.9090,  0.2022]])
#  tensor([[ 9.4646],
#         [-0.8544],
#         [ 4.7659],
#         [11.6455],
#         [-5.9790],
#         [ 2.0468],
#         [ 8.7652],
#         [ 4.5929],
#         [ 7.5734],
#         [ 5.3232]])
# tensor([[ 1.8067,  0.1508],
#         [ 0.5271, -0.6258],
#         [-0.6844,  1.0531],
#         [-0.5525,  1.0594],
#         [-0.4258,  0.4191],
#         [ 2.4033, -0.8507],
#         [ 0.0277, -0.9955],
#         [-0.1540, -0.6381],
#         [-0.6879,  0.4297],
#         [-1.4896,  1.4228]])
#  tensor([[ 7.2898],
#         [ 7.3746],
#         [-0.7486],
#         [-0.5091],
#         [ 1.9188],
#         [11.9060],
#         [ 7.6137],
#         [ 6.0581],
#         [ 1.3789],
#         [-3.6029]])
# tensor([[ 0.1636, -0.3474],
#         [ 0.3606,  0.1158],
#         [-1.1230, -1.0315],
#         [-1.0752,  2.0893],
#         [ 0.9153,  1.4863],
#         [ 0.6737, -1.0793],
#         [ 1.4757, -0.8028],
#         [ 0.4554, -0.2070],
#         [-1.1566,  0.3823],
#         [ 0.3956,  0.5898]])
#  tensor([[ 5.7200],
#         [ 4.5198],
#         [ 5.4688],
#         [-5.0432],
#         [ 0.9668],
#         [ 9.2118],
#         [ 9.8815],
#         [ 5.8119],
#         [ 0.5821],
#         [ 2.9817]])
# tensor([[ 0.5834, -0.7235],
#         [ 0.0285,  0.4951],
#         [-0.4431,  0.2876],
#         [ 1.1447,  0.2999],
#         [ 2.0090,  1.5157],
#         [ 0.8940, -0.4263],
#         [-0.3371,  0.3525],
#         [ 0.6897, -2.0306],
#         [ 0.1864, -0.0195],
#         [-1.4050, -0.8304]])
#  tensor([[ 7.8355],
#         [ 2.5668],
#         [ 2.3477],
#         [ 5.4630],
#         [ 3.0511],
#         [ 7.4394],
#         [ 2.3273],
#         [12.4926],
#         [ 4.6391],
#         [ 4.1988]])
# tensor([[-0.1578, -1.2525],
#         [ 0.5780, -0.2078],
#         [ 0.8774,  1.0285],
#         [-0.4260, -2.2492],
#         [ 1.7321, -2.2494],
#         [-0.9729,  0.0695],
#         [ 0.5142,  1.8477],
#         [-1.3485, -0.5873],
#         [ 0.8555,  1.2502],
#         [ 0.0511, -0.9747]])
#  tensor([[ 8.1461],
#         [ 6.0540],
#         [ 2.4465],
#         [11.0008],
#         [15.3204],
#         [ 2.0214],
#         [-1.0580],
#         [ 3.5138],
#         [ 1.6535],
#         [ 7.6126]])
# tensor([[-2.1674,  0.4301],
#         [-0.2799,  0.9289],
#         [-1.0012, -0.3419],
#         [ 2.9093, -0.5916],
#         [ 0.4713, -1.0439],
#         [ 0.6819,  0.6319],
#         [-0.7159,  0.0777],
#         [-0.5264,  0.1179],
#         [-0.2035,  0.8225],
#         [-0.1957, -0.1319]])
#  tensor([[-1.5904],
#         [ 0.4756],
#         [ 3.3688],
#         [12.0376],
#         [ 8.6782],
#         [ 3.4254],
#         [ 2.4976],
#         [ 2.7332],
#         [ 1.0080],
#         [ 4.2441]])
# tensor([[-1.2214,  0.5209],
#         [ 0.0763, -0.5108],
#         [ 0.9534, -0.8348],
#         [ 1.6885, -0.1014],
#         [-1.0380, -1.4332],
#         [-1.7192,  0.6387],
#         [-1.0188,  1.0818],
#         [-0.9849,  0.5866],
#         [-0.5123, -1.1426],
#         [ 1.6208, -0.5161]])
#  tensor([[-0.0288],
#         [ 6.1009],
#         [ 8.9558],
#         [ 7.9159],
#         [ 7.0166],
#         [-1.4115],
#         [-1.5067],
#         [ 0.2325],
#         [ 7.0464],
#         [ 9.1883]])
# tensor([[-6.6923e-01,  2.8557e-01],
#         [-5.3740e-01,  4.8248e-02],
#         [ 9.0021e-01, -5.5248e-01],
#         [ 8.1065e-01, -1.3695e-01],
#         [ 2.0169e+00,  1.9490e-01],
#         [-1.0131e+00, -1.3512e+00],
#         [-1.6509e+00, -3.9712e-01],
#         [ 6.3593e-01, -1.4853e+00],
#         [-4.9629e-02,  9.6283e-01],
#         [ 2.0530e-04,  1.3020e+00]])
#  tensor([[ 1.8826],
#         [ 2.9548],
#         [ 7.8888],
#         [ 6.2826],
#         [ 7.5648],
#         [ 6.7602],
#         [ 2.2362],
#         [10.5362],
#         [ 0.8280],
#         [-0.2298]])
# tensor([[-0.4049,  0.8253],
#         [ 1.2213,  1.2215],
#         [ 0.8980,  0.2908],
#         [-0.5416,  0.5387],
#         [-0.9339, -1.9360],
#         [-0.4119,  0.9884],
#         [ 1.4028,  0.8393],
#         [-0.4577, -0.2509],
#         [ 1.4057, -0.1328],
#         [-0.9530, -1.4172]])
#  tensor([[5.7265e-01],
#         [2.4808e+00],
#         [5.0015e+00],
#         [1.2982e+00],
#         [8.9245e+00],
#         [4.2049e-03],
#         [4.1518e+00],
#         [4.1460e+00],
#         [7.4599e+00],
#         [7.1189e+00]])

# %% [markdown]
# 当我们运行迭代时，我们会连续地获得不同的小批量，直至遍历完整个数据集。
# 上面实现的迭代对教学来说很好，但它的执行效率很低，可能会在实际问题上陷入麻烦。
# 例如，它要求我们将所有数据加载到内存中，并执行大量的随机内存访问。
# 在深度学习框架中实现的内置迭代器效率要高得多，
# 它可以处理存储在文件中的数据和数据流提供的数据。
#
# ## 初始化模型参数
#
# [**在我们开始用小批量随机梯度下降优化我们的模型参数之前**]，
# (**我们需要先有一些参数**)。
# 在下面的代码中，我们通过从均值为0、标准差为0.01的正态分布中采样随机数来初始化权重，
# 并将偏置初始化为0。

# %%
w = torch.normal(0, 0.01, size=(2,1), requires_grad=True)          # w =  2行一列的均值为0、标准差为0.01的正态分布中采样随机数
b = torch.zeros(1, requires_grad=True)

# %% [markdown]
# 在初始化参数之后，我们的任务是更新这些参数，直到这些参数足够拟合我们的数据。
# 每次更新都需要计算损失函数关于模型参数的梯度。
# 有了这个梯度，我们就可以向减小损失的方向更新每个参数。
# 因为手动计算梯度很枯燥而且容易出错，所以没有人会手动计算梯度。
# 我们使用 :numref:`sec_autograd`中引入的自动微分来计算梯度。
#
# ## 定义模型
#
# 接下来，我们必须[**定义模型，将模型的输入和参数同模型的输出关联起来。**]
# 回想一下，要计算线性模型的输出，
# 我们只需计算输入特征$\mathbf{X}$和模型权重$\mathbf{w}$的矩阵-向量乘法后加上偏置$b$。
# 注意，上面的$\mathbf{Xw}$是一个向量，而$b$是一个标量。
# 回想一下 :numref:`subsec_broadcasting`中描述的广播机制：
# 当我们用一个向量加一个标量时，标量会被加到向量的每个分量上。

# %%
def linreg(X, w, b):  #@save
    """线性回归模型"""
    return torch.matmul(X, w) + b

# %% [markdown]
# ## [**定义损失函数**]
#
# 因为需要计算损失函数的梯度，所以我们应该先定义损失函数。
# 这里我们使用 :numref:`sec_linear_regression`中描述的平方损失函数。
# 在实现中，我们需要将真实值`y`的形状转换为和预测值`y_hat`的形状相同。

# %%
def squared_loss(y_hat, y):  #@save
    """均方损失"""
    return (y_hat - y.reshape(y_hat.shape)) ** 2 / 2

# %% [markdown]
# ## (**定义优化算法**)
#
# 正如我们在 :numref:`sec_linear_regression`中讨论的，线性回归有解析解。
# 尽管线性回归有解析解，但本书中的其他模型却没有。
# 这里我们介绍小批量随机梯度下降。
#
# 在每一步中，使用从数据集中随机抽取的一个小批量，然后根据参数计算损失的梯度。
# 接下来，朝着减少损失的方向更新我们的参数。
# 下面的函数实现小批量随机梯度下降更新。
# 该函数接受模型参数集合、学习速率和批量大小作为输入。每
# 一步更新的大小由学习速率`lr`决定。
# 因为我们计算的损失是一个批量样本的总和，所以我们用批量大小（`batch_size`）
# 来规范化步长，这样步长大小就不会取决于我们对批量大小的选择。

# %%
def sgd(params, lr, batch_size):  #@save
    """小批量随机梯度下降"""
    i = 0
    with torch.no_grad():
        for param in params:
            i += 1
            print(i)
            param -= lr * param.grad / batch_size 
            print(param.grad)         
            param.grad.zero_()

# %% [markdown]
# ## 梯度优化算法
# ![Alt text](image.png)

# %% [markdown]
# ## 训练
#
# 现在我们已经准备好了模型训练所有需要的要素，可以实现主要的[**训练过程**]部分了。
# 理解这段代码至关重要，因为从事深度学习后，
# 相同的训练过程几乎一遍又一遍地出现。
# 在每次迭代中，我们读取一小批量训练样本，并通过我们的模型来获得一组预测。
# 计算完损失后，我们开始反向传播，存储每个参数的梯度。
# 最后，我们调用优化算法`sgd`来更新模型参数。
#
# 概括一下，我们将执行以下循环：
#
# * 初始化参数
# * 重复以下训练，直到完成
#     * 计算梯度$\mathbf{g} \leftarrow \partial_{(\mathbf{w},b)} \frac{1}{|\mathcal{B}|} \sum_{i \in \mathcal{B}} l(\mathbf{x}^{(i)}, y^{(i)}, \mathbf{w}, b)$
#     * 更新参数$(\mathbf{w}, b) \leftarrow (\mathbf{w}, b) - \eta \mathbf{g}$
#
# 在每个*迭代周期*（epoch）中，我们使用`data_iter`函数遍历整个数据集，
# 并将训练数据集中所有样本都使用一次（假设样本数能够被批量大小整除）。
# 这里的迭代周期个数`num_epochs`和学习率`lr`都是超参数，分别设为3和0.03。
# 设置超参数很棘手，需要通过反复试验进行调整。
# 我们现在忽略这些细节，以后会在 :numref:`chap_optimization`中详细介绍。

# %%
lr = 0.03
num_epochs = 3
net = linreg
loss = squared_loss
i = 0

# %%
for epoch in range(num_epochs):
    for X, y in data_iter(batch_size, features, labels):      #因为 batch_size = 10， all_size = 1000 ,每次for循环100次
        i += 1
        l = loss(net(X, w, b), y)  # X和y的小批量损失
        # 因为l形状是(batch_size,1)，而不是一个标量。l中的所有元素被加到一起，
        # 并以此计算关于[w,b]的梯度
        print(i,b)
        l.sum().backward()
        # print(w,b)
        sgd([w, b], lr, batch_size)  # 使用参数的梯度更新参数
    with torch.no_grad():
        train_l = loss(net(features, w, b), labels)
        print(f'epoch {epoch + 1}, loss {float(train_l.mean()):f}')
# Out:
# 1 tensor([0.], requires_grad=True)
# 1
# tensor([[-19.9026],
#         [ 51.4798]])
# 2
# tensor([-56.3597])
# 2 tensor([0.1691], requires_grad=True)
# 1
# tensor([[-32.3684],
#         [ 13.3096]])
# 2
# tensor([-46.5320])
# 3 tensor([0.3087], requires_grad=True)
# 1
# tensor([[-42.7550],
#         [ 60.8792]])
# 2
# tensor([-52.9895])
# 4 tensor([0.4676], requires_grad=True)
# 1
# tensor([[-23.9084],
#         [ 47.9863]])
# 2
# tensor([-44.3373])
# 5 tensor([0.6007], requires_grad=True)
# 1
# tensor([[-2.3018],
#         [38.1523]])
# 2
# tensor([-38.1972])
# 6 tensor([0.7152], requires_grad=True)
# 1
# tensor([[-16.3052],
#         [ 33.2612]])
# 2
# tensor([-36.1717])
# 7 tensor([0.8238], requires_grad=True)
# 1
# tensor([[-1.9316],
#         [44.8320]])
# 2
# tensor([-44.3543])
# 8 tensor([0.9568], requires_grad=True)
# 1
# tensor([[-5.8094],
#         [14.9277]])
# 2
# tensor([-17.3602])
# 9 tensor([1.0089], requires_grad=True)
# 1
# tensor([[-16.1646],
#         [ 49.7773]])
# 2
# tensor([-47.6584])
# 10 tensor([1.1519], requires_grad=True)
# 1
# tensor([[-9.9540],
#         [ 5.1149]])
# 2
# tensor([-25.9695])
# 11 tensor([1.2298], requires_grad=True)
# 1
# tensor([[-30.4647],
#         [ 23.6523]])
# 2
# tensor([-33.6499])
# 12 tensor([1.3307], requires_grad=True)
# 1
# tensor([[-3.1046],
#         [ 9.5030]])
# 2
# tensor([-20.1464])
# 13 tensor([1.3912], requires_grad=True)
# 1
# tensor([[-4.1642],
#         [ 7.3325]])
# 2
# tensor([-22.6806])
# 14 tensor([1.4592], requires_grad=True)
# 1
# tensor([[-17.5442],
#         [  3.6790]])
# 2
# tensor([-22.8518])
# 15 tensor([1.5278], requires_grad=True)
# 1
# tensor([[-25.1125],
#         [  2.4309]])
# 2
# tensor([-24.0465])
# 16 tensor([1.5999], requires_grad=True)
# 1
# tensor([[ 0.2070],
#         [19.2977]])
# 2
# tensor([-23.1402])
# 17 tensor([1.6693], requires_grad=True)
# 1
# tensor([[-5.2147],
#         [ 8.1147]])
# 2
# tensor([-24.4206])
# 18 tensor([1.7426], requires_grad=True)
# 1
# tensor([[-3.5049],
#         [15.8680]])
# 2
# tensor([-26.7490])
# 19 tensor([1.8228], requires_grad=True)
# 1
# tensor([[-15.4774],
#         [  8.8017]])
# 2
# tensor([-21.3056])
# 20 tensor([1.8868], requires_grad=True)
# 1
# tensor([[-26.8990],
#         [ 42.6256]])
# 2
# tensor([-19.5513])
# 21 tensor([1.9454], requires_grad=True)
# 1
# tensor([[-13.1248],
#         [ 13.5960]])
# 2
# tensor([-27.8723])
# 22 tensor([2.0290], requires_grad=True)
# 1
# tensor([[-4.4572],
#         [-2.6254]])
# 2
# tensor([-16.8042])
# 23 tensor([2.0794], requires_grad=True)
# 1
# tensor([[-8.8909],
#         [23.6364]])
# 2
# tensor([-9.3755])
# 24 tensor([2.1076], requires_grad=True)
# 1
# tensor([[-11.7651],
#         [ 15.8675]])
# 2
# tensor([-22.7777])
# 25 tensor([2.1759], requires_grad=True)
# 1
# tensor([[-0.3201],
#         [13.1750]])
# 2
# tensor([-15.6764])
# 26 tensor([2.2229], requires_grad=True)
# 1
# tensor([[-6.8843],
#         [20.0759]])
# 2
# tensor([-21.6410])
# 27 tensor([2.2879], requires_grad=True)
# 1
# tensor([[-28.9317],
#         [ 18.5737]])
# 2
# tensor([-24.6672])
# 28 tensor([2.3619], requires_grad=True)
# 1
# tensor([[-7.8366],
#         [ 8.2426]])
# 2
# tensor([-23.3444])
# 29 tensor([2.4319], requires_grad=True)
# 1
# tensor([[1.0274],
#         [7.3212]])
# 2
# tensor([-15.6164])
# 30 tensor([2.4787], requires_grad=True)
# 1
# tensor([[-7.4938],
#         [14.9641]])
# 2
# tensor([-12.7718])
# 31 tensor([2.5171], requires_grad=True)
# 1
# tensor([[-14.1065],
#         [ 20.1695]])
# 2
# tensor([-25.0976])
# 32 tensor([2.5923], requires_grad=True)
# 1
# tensor([[-10.2688],
#         [  5.9353]])
# 2
# tensor([-15.9598])
# 33 tensor([2.6402], requires_grad=True)
# 1
# tensor([[-8.3703],
#         [ 7.0595]])
# 2
# tensor([-8.7869])
# 34 tensor([2.6666], requires_grad=True)
# 1
# tensor([[-11.2242],
#         [ 17.4850]])
# 2
# tensor([-15.0434])
# 35 tensor([2.7117], requires_grad=True)
# 1
# tensor([[-14.6676],
#         [ 22.6183]])
# 2
# tensor([-20.1362])
# 36 tensor([2.7721], requires_grad=True)
# 1
# tensor([[-4.2154],
#         [ 6.8549]])
# 2
# tensor([-13.1908])
# 37 tensor([2.8117], requires_grad=True)
# 1
# tensor([[-3.5280],
#         [18.7896]])
# 2
# tensor([-21.2836])
# 38 tensor([2.8756], requires_grad=True)
# 1
# tensor([[-4.9545],
#         [24.0063]])
# 2
# tensor([-18.1404])
# 39 tensor([2.9300], requires_grad=True)
# 1
# tensor([[-11.3660],
#         [  8.6113]])
# 2
# tensor([-14.2248])
# 40 tensor([2.9726], requires_grad=True)
# 1
# tensor([[-23.4615],
#         [  9.9592]])
# 2
# tensor([-18.8344])
# 41 tensor([3.0292], requires_grad=True)
# 1
# tensor([[-2.3203],
#         [ 1.6979]])
# 2
# tensor([-4.7816])
# 42 tensor([3.0435], requires_grad=True)
# 1
# tensor([[-8.8139],
#         [28.0947]])
# 2
# tensor([-18.4426])
# 43 tensor([3.0988], requires_grad=True)
# 1
# tensor([[-19.2459],
#         [  8.5188]])
# 2
# tensor([-15.0218])
# 44 tensor([3.1439], requires_grad=True)
# 1
# tensor([[-0.9913],
#         [ 7.8606]])
# 2
# tensor([-8.7878])
# 45 tensor([3.1703], requires_grad=True)
# 1
# tensor([[-6.7166],
#         [ 6.4990]])
# 2
# tensor([-15.0652])
# 46 tensor([3.2154], requires_grad=True)
# 1
# tensor([[ 8.6712],
#         [13.3819]])
# 2
# tensor([-11.2719])
# 47 tensor([3.2493], requires_grad=True)
# 1
# tensor([[-2.9287],
#         [13.4887]])
# 2
# tensor([-8.5989])
# 48 tensor([3.2751], requires_grad=True)
# 1
# tensor([[-5.5195],
#         [ 6.5330]])
# 2
# tensor([-10.5735])
# 49 tensor([3.3068], requires_grad=True)
# 1
# tensor([[-1.0683],
#         [ 3.6597]])
# 2
# tensor([-9.0821])
# 50 tensor([3.3340], requires_grad=True)
# 1
# tensor([[0.3447],
#         [6.6420]])
# 2
# tensor([-6.3557])
# 51 tensor([3.3531], requires_grad=True)
# 1
# tensor([[-4.0151],
#         [10.6541]])
# 2
# tensor([-6.0859])
# 52 tensor([3.3714], requires_grad=True)
# 1
# tensor([[-1.0355],
#         [ 3.9176]])
# 2
# tensor([-7.9729])
# 53 tensor([3.3953], requires_grad=True)
# 1
# tensor([[-4.7281],
#         [ 7.3964]])
# 2
# tensor([-9.5863])
# 54 tensor([3.4240], requires_grad=True)
# 1
# tensor([[-10.2803],
#         [  8.6111]])
# 2
# tensor([-7.0797])
# 55 tensor([3.4453], requires_grad=True)
# 1
# tensor([[-0.8949],
#         [ 4.4693]])
# 2
# tensor([-7.5222])
# 56 tensor([3.4678], requires_grad=True)
# 1
# tensor([[-3.8887],
#         [ 5.2034]])
# 2
# tensor([-7.8688])
# 57 tensor([3.4914], requires_grad=True)
# 1
# tensor([[-1.9984],
#         [ 2.5037]])
# 2
# tensor([-8.1036])
# 58 tensor([3.5158], requires_grad=True)
# 1
# tensor([[1.8999],
#         [5.4430]])
# 2
# tensor([-5.6236])
# 59 tensor([3.5326], requires_grad=True)
# 1
# tensor([[-3.3410],
#         [ 5.8038]])
# 2
# tensor([-9.0280])
# 60 tensor([3.5597], requires_grad=True)
# 1
# tensor([[-5.6348],
#         [ 9.8773]])
# 2
# tensor([-9.8137])
# 61 tensor([3.5891], requires_grad=True)
# 1
# tensor([[-4.8371],
#         [ 7.5425]])
# 2
# tensor([-7.1788])
# 62 tensor([3.6107], requires_grad=True)
# 1
# tensor([[-0.4321],
#         [ 5.4649]])
# 2
# tensor([-7.7426])
# 63 tensor([3.6339], requires_grad=True)
# 1
# tensor([[-7.3461],
#         [ 5.3372]])
# 2
# tensor([-4.8477])
# 64 tensor([3.6485], requires_grad=True)
# 1
# tensor([[-1.9638],
#         [ 8.1122]])
# 2
# tensor([-7.5082])
# 65 tensor([3.6710], requires_grad=True)
# 1
# tensor([[0.1993],
#         [3.4517]])
# 2
# tensor([-2.8665])
# 66 tensor([3.6796], requires_grad=True)
# 1
# tensor([[-1.1593],
#         [ 4.0773]])
# 2
# tensor([-5.8297])
# 67 tensor([3.6971], requires_grad=True)
# 1
# tensor([[-5.4481],
#         [ 9.7955]])
# 2
# tensor([-6.1717])
# 68 tensor([3.7156], requires_grad=True)
# 1
# tensor([[-3.6423],
#         [ 3.6560]])
# 2
# tensor([-4.1632])
# 69 tensor([3.7281], requires_grad=True)
# 1
# tensor([[-4.2167],
#         [ 4.7418]])
# 2
# tensor([-4.0006])
# 70 tensor([3.7401], requires_grad=True)
# 1
# tensor([[1.0522],
#         [6.3673]])
# 2
# tensor([-2.7480])
# 71 tensor([3.7483], requires_grad=True)
# 1
# tensor([[-0.9716],
#         [ 4.6537]])
# 2
# tensor([-3.8384])
# 72 tensor([3.7598], requires_grad=True)
# 1
# tensor([[-2.6504],
#         [ 6.7940]])
# 2
# tensor([-3.3778])
# 73 tensor([3.7700], requires_grad=True)
# 1
# tensor([[-6.2342],
#         [ 3.3594]])
# 2
# tensor([-5.0870])
# 74 tensor([3.7852], requires_grad=True)
# 1
# tensor([[-2.9651],
#         [ 4.7586]])
# 2
# tensor([-7.0361])
# 75 tensor([3.8063], requires_grad=True)
# 1
# tensor([[-2.1899],
#         [ 4.9646]])
# 2
# tensor([-4.4584])
# 76 tensor([3.8197], requires_grad=True)
# 1
# tensor([[-0.1639],
#         [ 2.5810]])
# 2
# tensor([-3.9077])
# 77 tensor([3.8314], requires_grad=True)
# 1
# tensor([[2.3811],
#         [4.1118]])
# 2
# tensor([-2.5791])
# 78 tensor([3.8392], requires_grad=True)
# 1
# tensor([[1.0304],
#         [6.6154]])
# 2
# tensor([-4.2800])
# 79 tensor([3.8520], requires_grad=True)
# 1
# tensor([[-3.4890],
#         [ 4.9799]])
# 2
# tensor([-3.9016])
# 80 tensor([3.8637], requires_grad=True)
# 1
# tensor([[-3.1660],
#         [ 3.0178]])
# 2
# tensor([-4.8739])
# 81 tensor([3.8783], requires_grad=True)
# 1
# tensor([[-3.3764],
#         [ 2.2170]])
# 2
# tensor([-2.6631])
# 82 tensor([3.8863], requires_grad=True)
# 1
# tensor([[0.1047],
#         [5.8470]])
# 2
# tensor([-3.9458])
# 83 tensor([3.8982], requires_grad=True)
# 1
# tensor([[-0.5461],
#         [ 2.1926]])
# 2
# tensor([-3.3983])
# 84 tensor([3.9084], requires_grad=True)
# 1
# tensor([[-0.9010],
#         [ 2.5416]])
# 2
# tensor([-2.5491])
# 85 tensor([3.9160], requires_grad=True)
# 1
# tensor([[-1.5857],
#         [ 2.5215]])
# 2
# tensor([-2.5282])
# 86 tensor([3.9236], requires_grad=True)
# 1
# tensor([[-3.9661],
#         [ 2.2826]])
# 2
# tensor([-2.3285])
# 87 tensor([3.9306], requires_grad=True)
# 1
# tensor([[0.4999],
#         [1.4434]])
# 2
# tensor([-1.2986])
# 88 tensor([3.9345], requires_grad=True)
# 1
# tensor([[-1.1633],
#         [ 0.8862]])
# 2
# tensor([-2.5294])
# 89 tensor([3.9421], requires_grad=True)
# 1
# tensor([[-1.3422],
#         [ 4.8544]])
# 2
# tensor([-4.3875])
# 90 tensor([3.9552], requires_grad=True)
# 1
# tensor([[-2.4609],
#         [ 1.4815]])
# 2
# tensor([-3.2520])
# 91 tensor([3.9650], requires_grad=True)
# 1
# tensor([[1.2102],
#         [1.5804]])
# 2
# tensor([-2.0578])
# 92 tensor([3.9712], requires_grad=True)
# 1
# tensor([[-1.5708],
#         [ 3.6172]])
# 2
# tensor([-3.8779])
# 93 tensor([3.9828], requires_grad=True)
# 1
# tensor([[-0.8925],
#         [ 3.2910]])
# 2
# tensor([-2.4823])
# 94 tensor([3.9902], requires_grad=True)
# 1
# tensor([[-1.4737],
#         [ 1.6378]])
# 2
# tensor([-2.4186])
# 95 tensor([3.9975], requires_grad=True)
# 1
# tensor([[-1.6177],
#         [ 4.0496]])
# 2
# tensor([-2.5548])
# 96 tensor([4.0052], requires_grad=True)
# 1
# tensor([[-0.4222],
#         [-0.2203]])
# 2
# tensor([-1.1656])
# 97 tensor([4.0087], requires_grad=True)
# 1
# tensor([[-0.8855],
#         [ 1.6841]])
# 2
# tensor([-2.2432])
# 98 tensor([4.0154], requires_grad=True)
# 1
# tensor([[-0.3530],
#         [ 0.8346]])
# 2
# tensor([-2.0372])
# 99 tensor([4.0215], requires_grad=True)
# 1
# tensor([[-0.7107],
#         [ 1.0259]])
# 2
# tensor([-1.8447])
# 100 tensor([4.0270], requires_grad=True)
# 1
# tensor([[-0.6473],
#         [ 0.7108]])
# 2
# tensor([-2.0662])
# epoch 1, loss 0.028196
# 101 tensor([4.0332], requires_grad=True)
# 1
# tensor([[0.0395],
#         [1.9694]])
# 2
# tensor([-1.4960])
# 102 tensor([4.0377], requires_grad=True)
# 1
# tensor([[-1.4457],
#         [ 1.1726]])
# 2
# tensor([-2.4462])
# 103 tensor([4.0451], requires_grad=True)
# 1
# tensor([[-0.5857],
#         [ 0.8317]])
# 2
# tensor([-2.1166])
# 104 tensor([4.0514], requires_grad=True)
# 1
# tensor([[-0.0811],
#         [ 0.0336]])
# 2
# tensor([-0.9842])
# 105 tensor([4.0544], requires_grad=True)
# 1
# tensor([[-0.3815],
#         [ 2.1947]])
# 2
# tensor([-1.6402])
# 106 tensor([4.0593], requires_grad=True)
# 1
# tensor([[-1.4956],
#         [ 1.5468]])
# 2
# tensor([-1.5756])
# 107 tensor([4.0640], requires_grad=True)
# 1
# tensor([[-0.5281],
#         [ 1.2526]])
# 2
# tensor([-1.2631])
# 108 tensor([4.0678], requires_grad=True)
# 1
# tensor([[0.3591],
#         [1.1242]])
# 2
# tensor([-0.7041])
# 109 tensor([4.0699], requires_grad=True)
# 1
# tensor([[-1.0762],
#         [ 0.8152]])
# 2
# tensor([-1.7828])
# 110 tensor([4.0753], requires_grad=True)
# 1
# tensor([[-0.6643],
#         [ 0.4476]])
# 2
# tensor([-1.3695])
# 111 tensor([4.0794], requires_grad=True)
# 1
# tensor([[-0.6621],
#         [ 1.7975]])
# 2
# tensor([-1.7037])
# 112 tensor([4.0845], requires_grad=True)
# 1
# tensor([[-0.4964],
#         [ 1.0103]])
# 2
# tensor([-1.1130])
# 113 tensor([4.0878], requires_grad=True)
# 1
# tensor([[-0.2750],
#         [ 0.1964]])
# 2
# tensor([-0.8429])
# 114 tensor([4.0903], requires_grad=True)
# 1
# tensor([[-0.4128],
#         [ 1.3907]])
# 2
# tensor([-1.4249])
# 115 tensor([4.0946], requires_grad=True)
# 1
# tensor([[-0.2179],
#         [-0.0805]])
# 2
# tensor([-0.7145])
# 116 tensor([4.0968], requires_grad=True)
# 1
# tensor([[-0.6536],
#         [ 0.6534]])
# 2
# tensor([-0.3102])
# 117 tensor([4.0977], requires_grad=True)
# 1
# tensor([[-0.4972],
#         [ 0.1537]])
# 2
# tensor([-0.2615])
# 118 tensor([4.0985], requires_grad=True)
# 1
# tensor([[-0.1171],
#         [ 1.2277]])
# 2
# tensor([-1.0395])
# 119 tensor([4.1016], requires_grad=True)
# 1
# tensor([[-0.5081],
#         [ 0.9501]])
# 2
# tensor([-1.2969])
# 120 tensor([4.1055], requires_grad=True)
# 1
# tensor([[-1.2178],
#         [ 1.1576]])
# 2
# tensor([-1.3484])
# 121 tensor([4.1095], requires_grad=True)
# 1
# tensor([[-0.5556],
#         [ 0.2671]])
# 2
# tensor([-0.9973])
# 122 tensor([4.1125], requires_grad=True)
# 1
# tensor([[-0.2818],
#         [ 1.1336]])
# 2
# tensor([-0.8783])
# 123 tensor([4.1152], requires_grad=True)
# 1
# tensor([[0.4069],
#         [0.4973]])
# 2
# tensor([-0.5318])
# 124 tensor([4.1167], requires_grad=True)
# 1
# tensor([[-0.8751],
#         [ 1.2596]])
# 2
# tensor([-1.1256])
# 125 tensor([4.1201], requires_grad=True)
# 1
# tensor([[-0.7813],
#         [ 0.1960]])
# 2
# tensor([-0.6931])
# 126 tensor([4.1222], requires_grad=True)
# 1
# tensor([[-0.2374],
#         [ 0.9791]])
# 2
# tensor([-1.0292])
# 127 tensor([4.1253], requires_grad=True)
# 1
# tensor([[-1.0037],
#         [ 1.3316]])
# 2
# tensor([-0.4283])
# 128 tensor([4.1266], requires_grad=True)
# 1
# tensor([[-0.4193],
#         [ 0.6147]])
# 2
# tensor([-0.7792])
# 129 tensor([4.1289], requires_grad=True)
# 1
# tensor([[-0.2791],
#         [ 0.4343]])
# 2
# tensor([-0.9430])
# 130 tensor([4.1317], requires_grad=True)
# 1
# tensor([[-1.4927],
#         [ 1.0190]])
# 2
# tensor([-1.1515])
# 131 tensor([4.1352], requires_grad=True)
# 1
# tensor([[-0.4835],
#         [ 1.1872]])
# 2
# tensor([-0.7333])
# 132 tensor([4.1374], requires_grad=True)
# 1
# tensor([[-0.1207],
#         [ 1.0140]])
# 2
# tensor([-0.9848])
# 133 tensor([4.1404], requires_grad=True)
# 1
# tensor([[-0.6285],
#         [ 0.4759]])
# 2
# tensor([-0.4649])
# 134 tensor([4.1417], requires_grad=True)
# 1
# tensor([[-0.4095],
#         [ 0.4657]])
# 2
# tensor([-0.5755])
# 135 tensor([4.1435], requires_grad=True)
# 1
# tensor([[-0.2068],
#         [ 0.3250]])
# 2
# tensor([-0.3538])
# 136 tensor([4.1445], requires_grad=True)
# 1
# tensor([[-0.7308],
#         [ 0.1216]])
# 2
# tensor([-0.6938])
# 137 tensor([4.1466], requires_grad=True)
# 1
# tensor([[-0.3467],
#         [ 0.3968]])
# 2
# tensor([-0.5726])
# 138 tensor([4.1483], requires_grad=True)
# 1
# tensor([[0.0052],
#         [0.1700]])
# 2
# tensor([-0.5159])
# 139 tensor([4.1499], requires_grad=True)
# 1
# tensor([[-0.5296],
#         [ 0.4262]])
# 2
# tensor([-0.6850])
# 140 tensor([4.1519], requires_grad=True)
# 1
# tensor([[-0.3360],
#         [ 0.1093]])
# 2
# tensor([-0.3921])
# 141 tensor([4.1531], requires_grad=True)
# 1
# tensor([[0.0819],
#         [0.8091]])
# 2
# tensor([-0.6267])
# 142 tensor([4.1550], requires_grad=True)
# 1
# tensor([[-0.1869],
#         [ 0.4153]])
# 2
# tensor([-0.4747])
# 143 tensor([4.1564], requires_grad=True)
# 1
# tensor([[-0.2008],
#         [ 0.3433]])
# 2
# tensor([-0.4458])
# 144 tensor([4.1578], requires_grad=True)
# 1
# tensor([[0.0685],
#         [0.2940]])
# 2
# tensor([-0.4896])
# 145 tensor([4.1592], requires_grad=True)
# 1
# tensor([[-0.3059],
#         [ 0.3596]])
# 2
# tensor([-0.5590])
# 146 tensor([4.1609], requires_grad=True)
# 1
# tensor([[-0.2847],
#         [ 0.5006]])
# 2
# tensor([-0.3977])
# 147 tensor([4.1621], requires_grad=True)
# 1
# tensor([[0.2086],
#         [0.6332]])
# 2
# tensor([-0.5675])
# 148 tensor([4.1638], requires_grad=True)
# 1
# tensor([[-0.0864],
#         [ 0.3449]])
# 2
# tensor([-0.3121])
# 149 tensor([4.1647], requires_grad=True)
# 1
# tensor([[0.0312],
#         [0.3266]])
# 2
# tensor([-0.3588])
# 150 tensor([4.1658], requires_grad=True)
# 1
# tensor([[-0.0808],
#         [ 0.3155]])
# 2
# tensor([-0.3913])
# 151 tensor([4.1670], requires_grad=True)
# 1
# tensor([[-0.0885],
#         [ 0.1009]])
# 2
# tensor([-0.1529])
# 152 tensor([4.1674], requires_grad=True)
# 1
# tensor([[-0.0177],
#         [ 0.3637]])
# 2
# tensor([-0.2936])
# 153 tensor([4.1683], requires_grad=True)
# 1
# tensor([[-0.1454],
#         [ 0.0312]])
# 2
# tensor([-0.2143])
# 154 tensor([4.1690], requires_grad=True)
# 1
# tensor([[0.0017],
#         [0.5432]])
# 2
# tensor([-0.4668])
# 155 tensor([4.1704], requires_grad=True)
# 1
# tensor([[-0.2590],
#         [ 0.3979]])
# 2
# tensor([-0.2030])
# 156 tensor([4.1710], requires_grad=True)
# 1
# tensor([[-0.4371],
#         [ 0.3640]])
# 2
# tensor([-0.5132])
# 157 tensor([4.1725], requires_grad=True)
# 1
# tensor([[-0.0191],
#         [ 0.1883]])
# 2
# tensor([-0.2550])
# 158 tensor([4.1733], requires_grad=True)
# 1
# tensor([[-0.1528],
#         [ 0.3935]])
# 2
# tensor([-0.3226])
# 159 tensor([4.1742], requires_grad=True)
# 1
# tensor([[-0.0625],
#         [ 0.3872]])
# 2
# tensor([-0.3180])
# 160 tensor([4.1752], requires_grad=True)
# 1
# tensor([[-0.1239],
#         [ 0.3961]])
# 2
# tensor([-0.4344])
# 161 tensor([4.1765], requires_grad=True)
# 1
# tensor([[-0.0315],
#         [ 0.1087]])
# 2
# tensor([-0.2293])
# 162 tensor([4.1772], requires_grad=True)
# 1
# tensor([[-0.1359],
#         [ 0.3710]])
# 2
# tensor([-0.3185])
# 163 tensor([4.1781], requires_grad=True)
# 1
# tensor([[-0.1609],
#         [ 0.3685]])
# 2
# tensor([-0.3032])
# 164 tensor([4.1791], requires_grad=True)
# 1
# tensor([[-0.1383],
#         [ 0.3284]])
# 2
# tensor([-0.2028])
# 165 tensor([4.1797], requires_grad=True)
# 1
# tensor([[-0.0657],
#         [ 0.1002]])
# 2
# tensor([-0.2223])
# 166 tensor([4.1803], requires_grad=True)
# 1
# tensor([[-0.0140],
#         [ 0.1926]])
# 2
# tensor([-0.1963])
# 167 tensor([4.1809], requires_grad=True)
# 1
# tensor([[0.0848],
#         [0.1419]])
# 2
# tensor([-0.1890])
# 168 tensor([4.1815], requires_grad=True)
# 1
# tensor([[-0.1105],
#         [ 0.0569]])
# 2
# tensor([-0.1549])
# 169 tensor([4.1820], requires_grad=True)
# 1
# tensor([[-0.1132],
#         [ 0.1297]])
# 2
# tensor([-0.2970])
# 170 tensor([4.1828], requires_grad=True)
# 1
# tensor([[0.0011],
#         [0.2998]])
# 2
# tensor([-0.2618])
# 171 tensor([4.1836], requires_grad=True)
# 1
# tensor([[-0.1553],
#         [ 0.2402]])
# 2
# tensor([-0.1930])
# 172 tensor([4.1842], requires_grad=True)
# 1
# tensor([[0.0287],
#         [0.2520]])
# 2
# tensor([-0.1132])
# 173 tensor([4.1845], requires_grad=True)
# 1
# tensor([[-0.1572],
#         [ 0.0336]])
# 2
# tensor([-0.0934])
# 174 tensor([4.1848], requires_grad=True)
# 1
# tensor([[-0.0972],
#         [ 0.1412]])
# 2
# tensor([-0.1487])
# 175 tensor([4.1853], requires_grad=True)
# 1
# tensor([[-0.0208],
#         [ 0.1542]])
# 2
# tensor([-0.1878])
# 176 tensor([4.1858], requires_grad=True)
# 1
# tensor([[0.0410],
#         [0.0384]])
# 2
# tensor([-0.1009])
# 177 tensor([4.1861], requires_grad=True)
# 1
# tensor([[-0.1914],
#         [ 0.1857]])
# 2
# tensor([-0.1624])
# 178 tensor([4.1866], requires_grad=True)
# 1
# tensor([[0.1798],
#         [0.1074]])
# 2
# tensor([-0.1375])
# 179 tensor([4.1870], requires_grad=True)
# 1
# tensor([[-0.0649],
#         [ 0.0566]])
# 2
# tensor([-0.0959])
# 180 tensor([4.1873], requires_grad=True)
# 1
# tensor([[0.0456],
#         [0.1328]])
# 2
# tensor([-0.1106])
# 181 tensor([4.1877], requires_grad=True)
# 1
# tensor([[-0.1302],
#         [ 0.2000]])
# 2
# tensor([-0.0334])
# 182 tensor([4.1878], requires_grad=True)
# 1
# tensor([[-0.0023],
#         [ 0.0914]])
# 2
# tensor([-0.1167])
# 183 tensor([4.1881], requires_grad=True)
# 1
# tensor([[-0.0250],
#         [ 0.0928]])
# 2
# tensor([-0.0690])
# 184 tensor([4.1883], requires_grad=True)
# 1
# tensor([[0.0430],
#         [0.1167]])
# 2
# tensor([-0.1568])
# 185 tensor([4.1888], requires_grad=True)
# 1
# tensor([[-0.0834],
#         [ 0.0889]])
# 2
# tensor([-0.1770])
# 186 tensor([4.1893], requires_grad=True)
# 1
# tensor([[-0.0455],
#         [ 0.1165]])
# 2
# tensor([-0.1451])
# 187 tensor([4.1898], requires_grad=True)
# 1
# tensor([[-0.0878],
#         [ 0.0706]])
# 2
# tensor([-0.1340])
# 188 tensor([4.1902], requires_grad=True)
# 1
# tensor([[-0.0881],
#         [ 0.0938]])
# 2
# tensor([-0.0990])
# 189 tensor([4.1905], requires_grad=True)
# 1
# tensor([[-0.0558],
#         [ 0.2489]])
# 2
# tensor([-0.0850])
# 190 tensor([4.1907], requires_grad=True)
# 1
# tensor([[-0.0388],
#         [ 0.0807]])
# 2
# tensor([-0.1289])
# 191 tensor([4.1911], requires_grad=True)
# 1
# tensor([[-0.0571],
#         [ 0.1226]])
# 2
# tensor([-0.0449])
# 192 tensor([4.1912], requires_grad=True)
# 1
# tensor([[-0.0100],
#         [ 0.0709]])
# 2
# tensor([-0.1029])
# 193 tensor([4.1915], requires_grad=True)
# 1
# tensor([[-0.1376],
#         [ 0.1733]])
# 2
# tensor([-0.1578])
# 194 tensor([4.1920], requires_grad=True)
# 1
# tensor([[-0.0026],
#         [ 0.1199]])
# 2
# tensor([-0.1319])
# 195 tensor([4.1924], requires_grad=True)
# 1
# tensor([[-0.0424],
#         [-0.0428]])
# 2
# tensor([-0.0535])
# 196 tensor([4.1926], requires_grad=True)
# 1
# tensor([[-0.0167],
#         [ 0.0306]])
# 2
# tensor([-0.0888])
# 197 tensor([4.1928], requires_grad=True)
# 1
# tensor([[-0.0799],
#         [ 0.0011]])
# 2
# tensor([-0.1102])
# 198 tensor([4.1932], requires_grad=True)
# 1
# tensor([[-0.0011],
#         [ 0.0678]])
# 2
# tensor([-0.0643])
# 199 tensor([4.1934], requires_grad=True)
# 1
# tensor([[-0.0563],
#         [ 0.0408]])
# 2
# tensor([-0.0664])
# 200 tensor([4.1936], requires_grad=True)
# 1
# tensor([[-0.0801],
#         [ 0.0512]])
# 2
# tensor([-0.0558])
# epoch 2, loss 0.000099
# 201 tensor([4.1937], requires_grad=True)
# 1
# tensor([[-0.1308],
#         [ 0.1586]])
# 2
# tensor([-0.0936])
# 202 tensor([4.1940], requires_grad=True)
# 1
# tensor([[0.0416],
#         [0.0624]])
# 2
# tensor([-0.0893])
# 203 tensor([4.1943], requires_grad=True)
# 1
# tensor([[0.0342],
#         [0.0908]])
# 2
# tensor([-0.0701])
# 204 tensor([4.1945], requires_grad=True)
# 1
# tensor([[-0.0064],
#         [ 0.0665]])
# 2
# tensor([-0.1264])
# 205 tensor([4.1949], requires_grad=True)
# 1
# tensor([[0.0219],
#         [0.0367]])
# 2
# tensor([-0.1167])
# 206 tensor([4.1952], requires_grad=True)
# 1
# tensor([[-0.0142],
#         [ 0.0400]])
# 2
# tensor([-0.0929])
# 207 tensor([4.1955], requires_grad=True)
# 1
# tensor([[-0.0265],
#         [ 0.0186]])
# 2
# tensor([-0.0482])
# 208 tensor([4.1956], requires_grad=True)
# 1
# tensor([[-0.0571],
#         [ 0.0625]])
# 2
# tensor([-0.0131])
# 209 tensor([4.1957], requires_grad=True)
# 1
# tensor([[0.0195],
#         [0.0046]])
# 2
# tensor([-0.0288])
# 210 tensor([4.1958], requires_grad=True)
# 1
# tensor([[-0.0021],
#         [-0.0399]])
# 2
# tensor([-0.0408])
# 211 tensor([4.1959], requires_grad=True)
# 1
# tensor([[-0.0659],
#         [ 0.0004]])
# 2
# tensor([0.0172])
# 212 tensor([4.1958], requires_grad=True)
# 1
# tensor([[-0.0343],
#         [-0.0723]])
# 2
# tensor([0.0113])
# 213 tensor([4.1958], requires_grad=True)
# 1
# tensor([[-0.0284],
#         [ 0.0653]])
# 2
# tensor([-0.0237])
# 214 tensor([4.1959], requires_grad=True)
# 1
# tensor([[0.0344],
#         [0.0306]])
# 2
# tensor([-0.0379])
# 215 tensor([4.1960], requires_grad=True)
# 1
# tensor([[-0.0495],
#         [ 0.0228]])
# 2
# tensor([-0.0410])
# 216 tensor([4.1961], requires_grad=True)
# 1
# tensor([[-0.0123],
#         [ 0.0090]])
# 2
# tensor([0.0137])
# 217 tensor([4.1961], requires_grad=True)
# 1
# tensor([[-0.0649],
#         [-0.0262]])
# 2
# tensor([-0.0566])
# 218 tensor([4.1962], requires_grad=True)
# 1
# tensor([[0.0126],
#         [0.0022]])
# 2
# tensor([-0.0338])
# 219 tensor([4.1963], requires_grad=True)
# 1
# tensor([[0.0079],
#         [0.0377]])
# 2
# tensor([-0.0627])
# 220 tensor([4.1965], requires_grad=True)
# 1
# tensor([[-0.0101],
#         [ 0.0237]])
# 2
# tensor([-0.0512])
# 221 tensor([4.1967], requires_grad=True)
# 1
# tensor([[-0.1159],
#         [ 0.0685]])
# 2
# tensor([-0.1038])
# 222 tensor([4.1970], requires_grad=True)
# 1
# tensor([[0.0185],
#         [0.0665]])
# 2
# tensor([-0.0299])
# 223 tensor([4.1971], requires_grad=True)
# 1
# tensor([[-0.0280],
#         [ 0.0860]])
# 2
# tensor([0.0518])
# 224 tensor([4.1969], requires_grad=True)
# 1
# tensor([[0.0006],
#         [0.0227]])
# 2
# tensor([-0.0398])
# 225 tensor([4.1970], requires_grad=True)
# 1
# tensor([[-0.0402],
#         [ 0.0111]])
# 2
# tensor([-0.0138])
# 226 tensor([4.1971], requires_grad=True)
# 1
# tensor([[0.0105],
#         [0.0479]])
# 2
# tensor([-0.0467])
# 227 tensor([4.1972], requires_grad=True)
# 1
# tensor([[-0.0159],
#         [ 0.0279]])
# 2
# tensor([-0.0251])
# 228 tensor([4.1973], requires_grad=True)
# 1
# tensor([[0.0038],
#         [0.0698]])
# 2
# tensor([-0.0630])
# 229 tensor([4.1975], requires_grad=True)
# 1
# tensor([[0.0169],
#         [0.0267]])
# 2
# tensor([-0.0830])
# 230 tensor([4.1977], requires_grad=True)
# 1
# tensor([[0.0115],
#         [0.0184]])
# 2
# tensor([-0.0287])
# 231 tensor([4.1978], requires_grad=True)
# 1
# tensor([[-0.0827],
#         [ 0.0253]])
# 2
# tensor([-0.0062])
# 232 tensor([4.1978], requires_grad=True)
# 1
# tensor([[-0.0052],
#         [ 0.1617]])
# 2
# tensor([-0.1059])
# 233 tensor([4.1982], requires_grad=True)
# 1
# tensor([[0.0020],
#         [0.0325]])
# 2
# tensor([-0.0244])
# 234 tensor([4.1982], requires_grad=True)
# 1
# tensor([[-0.0161],
#         [ 0.0221]])
# 2
# tensor([-0.0326])
# 235 tensor([4.1983], requires_grad=True)
# 1
# tensor([[-0.0007],
#         [ 0.0419]])
# 2
# tensor([-0.0489])
# 236 tensor([4.1985], requires_grad=True)
# 1
# tensor([[-0.0031],
#         [ 0.0462]])
# 2
# tensor([-0.0007])
# 237 tensor([4.1985], requires_grad=True)
# 1
# tensor([[-0.0478],
#         [-0.0020]])
# 2
# tensor([-0.0002])
# 238 tensor([4.1985], requires_grad=True)
# 1
# tensor([[-0.0534],
#         [ 0.0092]])
# 2
# tensor([-0.0114])
# 239 tensor([4.1985], requires_grad=True)
# 1
# tensor([[-0.0526],
#         [ 0.0789]])
# 2
# tensor([-0.0695])
# 240 tensor([4.1987], requires_grad=True)
# 1
# tensor([[0.0278],
#         [0.0422]])
# 2
# tensor([0.0155])
# 241 tensor([4.1987], requires_grad=True)
# 1
# tensor([[ 0.0036],
#         [-0.0165]])
# 2
# tensor([-0.0376])
# 242 tensor([4.1988], requires_grad=True)
# 1
# tensor([[-0.0522],
#         [-0.0283]])
# 2
# tensor([0.0197])
# 243 tensor([4.1987], requires_grad=True)
# 1
# tensor([[0.0048],
#         [0.1050]])
# 2
# tensor([0.0172])
# 244 tensor([4.1987], requires_grad=True)
# 1
# tensor([[0.0250],
#         [0.0489]])
# 2
# tensor([-0.0075])
# 245 tensor([4.1987], requires_grad=True)
# 1
# tensor([[0.0028],
#         [0.0197]])
# 2
# tensor([0.0220])
# 246 tensor([4.1986], requires_grad=True)
# 1
# tensor([[-0.0248],
#         [ 0.0387]])
# 2
# tensor([0.0138])
# 247 tensor([4.1986], requires_grad=True)
# 1
# tensor([[-0.0407],
#         [-0.0087]])
# 2
# tensor([0.0094])
# 248 tensor([4.1986], requires_grad=True)
# 1
# tensor([[-0.0180],
#         [-0.0407]])
# 2
# tensor([-0.0115])
# 249 tensor([4.1986], requires_grad=True)
# 1
# tensor([[0.0085],
#         [0.0173]])
# 2
# tensor([0.0307])
# 250 tensor([4.1985], requires_grad=True)
# 1
# tensor([[-0.0113],
#         [-0.0249]])
# 2
# tensor([-0.0223])
# 251 tensor([4.1986], requires_grad=True)
# 1
# tensor([[-0.0127],
#         [ 0.0394]])
# 2
# tensor([-0.0383])
# 252 tensor([4.1987], requires_grad=True)
# 1
# tensor([[0.0516],
#         [0.0352]])
# 2
# tensor([-0.0031])
# 253 tensor([4.1987], requires_grad=True)
# 1
# tensor([[-0.0063],
#         [-0.0110]])
# 2
# tensor([-0.0384])
# 254 tensor([4.1988], requires_grad=True)
# 1
# tensor([[-0.0546],
#         [ 0.0259]])
# 2
# tensor([-0.0151])
# 255 tensor([4.1989], requires_grad=True)
# 1
# tensor([[0.0150],
#         [0.0148]])
# 2
# tensor([-0.0504])
# 256 tensor([4.1990], requires_grad=True)
# 1
# tensor([[-0.0120],
#         [ 0.0236]])
# 2
# tensor([-0.0855])
# 257 tensor([4.1993], requires_grad=True)
# 1
# tensor([[-0.0157],
#         [-0.0261]])
# 2
# tensor([0.0350])
# 258 tensor([4.1992], requires_grad=True)
# 1
# tensor([[-0.0080],
#         [ 0.0186]])
# 2
# tensor([-0.0251])
# 259 tensor([4.1992], requires_grad=True)
# 1
# tensor([[-0.0255],
#         [-0.0158]])
# 2
# tensor([-0.0070])
# 260 tensor([4.1993], requires_grad=True)
# 1
# tensor([[0.0085],
#         [0.0564]])
# 2
# tensor([-0.0867])
# 261 tensor([4.1995], requires_grad=True)
# 1
# tensor([[0.0168],
#         [0.0636]])
# 2
# tensor([0.0399])
# 262 tensor([4.1994], requires_grad=True)
# 1
# tensor([[-0.0162],
#         [ 0.0448]])
# 2
# tensor([-0.0194])
# 263 tensor([4.1995], requires_grad=True)
# 1
# tensor([[0.0365],
#         [0.0011]])
# 2
# tensor([-0.0215])
# 264 tensor([4.1995], requires_grad=True)
# 1
# tensor([[ 0.0118],
#         [-0.0246]])
# 2
# tensor([0.0324])
# 265 tensor([4.1994], requires_grad=True)
# 1
# tensor([[-0.0744],
#         [-0.0250]])
# 2
# tensor([-0.0303])
# 266 tensor([4.1995], requires_grad=True)
# 1
# tensor([[0.0319],
#         [0.0577]])
# 2
# tensor([0.0154])
# 267 tensor([4.1995], requires_grad=True)
# 1
# tensor([[ 0.0015],
#         [-0.0166]])
# 2
# tensor([0.0013])
# 268 tensor([4.1995], requires_grad=True)
# 1
# tensor([[0.0064],
#         [0.0192]])
# 2
# tensor([0.0120])
# 269 tensor([4.1994], requires_grad=True)
# 1
# tensor([[-0.0595],
#         [ 0.0119]])
# 2
# tensor([-0.0199])
# 270 tensor([4.1995], requires_grad=True)
# 1
# tensor([[-0.0377],
#         [ 0.0564]])
# 2
# tensor([-0.0305])
# 271 tensor([4.1996], requires_grad=True)
# 1
# tensor([[ 0.0479],
#         [-0.0179]])
# 2
# tensor([-0.0254])
# 272 tensor([4.1997], requires_grad=True)
# 1
# tensor([[0.0178],
#         [0.0099]])
# 2
# tensor([-0.0410])
# 273 tensor([4.1998], requires_grad=True)
# 1
# tensor([[-0.0288],
#         [-0.0091]])
# 2
# tensor([-0.0850])
# 274 tensor([4.2000], requires_grad=True)
# 1
# tensor([[0.0395],
#         [0.0337]])
# 2
# tensor([0.0109])
# 275 tensor([4.2000], requires_grad=True)
# 1
# tensor([[-0.0273],
#         [ 0.0503]])
# 2
# tensor([0.0084])
# 276 tensor([4.2000], requires_grad=True)
# 1
# tensor([[-0.0146],
#         [-0.0531]])
# 2
# tensor([-0.0006])
# 277 tensor([4.2000], requires_grad=True)
# 1
# tensor([[-0.0058],
#         [ 0.0368]])
# 2
# tensor([-0.0101])
# 278 tensor([4.2000], requires_grad=True)
# 1
# tensor([[0.0016],
#         [0.0046]])
# 2
# tensor([-0.0148])
# 279 tensor([4.2001], requires_grad=True)
# 1
# tensor([[0.0075],
#         [0.0196]])
# 2
# tensor([0.0395])
# 280 tensor([4.1999], requires_grad=True)
# 1
# tensor([[-0.0278],
#         [ 0.0444]])
# 2
# tensor([0.0638])
# 281 tensor([4.1997], requires_grad=True)
# 1
# tensor([[-0.0051],
#         [ 0.0009]])
# 2
# tensor([0.0178])
# 282 tensor([4.1997], requires_grad=True)
# 1
# tensor([[-0.0429],
#         [ 0.0479]])
# 2
# tensor([-0.0355])
# 283 tensor([4.1998], requires_grad=True)
# 1
# tensor([[ 0.0496],
#         [-0.0573]])
# 2
# tensor([-0.0335])
# 284 tensor([4.1999], requires_grad=True)
# 1
# tensor([[-0.0171],
#         [-0.0027]])
# 2
# tensor([-0.0452])
# 285 tensor([4.2000], requires_grad=True)
# 1
# tensor([[ 0.0293],
#         [-0.0231]])
# 2
# tensor([-0.0042])
# 286 tensor([4.2000], requires_grad=True)
# 1
# tensor([[0.0508],
#         [0.0678]])
# 2
# tensor([-0.0355])
# 287 tensor([4.2002], requires_grad=True)
# 1
# tensor([[0.0061],
#         [0.0099]])
# 2
# tensor([0.0083])
# 288 tensor([4.2001], requires_grad=True)
# 1
# tensor([[ 0.0206],
#         [-0.0170]])
# 2
# tensor([0.0031])
# 289 tensor([4.2001], requires_grad=True)
# 1
# tensor([[-0.0140],
#         [-0.0348]])
# 2
# tensor([0.0283])
# 290 tensor([4.2000], requires_grad=True)
# 1
# tensor([[-0.0087],
#         [ 0.0251]])
# 2
# tensor([-0.0040])
# 291 tensor([4.2000], requires_grad=True)
# 1
# tensor([[-0.0109],
#         [-0.0233]])
# 2
# tensor([-0.0285])
# 292 tensor([4.2001], requires_grad=True)
# 1
# tensor([[-0.0165],
#         [-0.0296]])
# 2
# tensor([-0.0524])
# 293 tensor([4.2003], requires_grad=True)
# 1
# tensor([[ 0.0290],
#         [-0.0354]])
# 2
# tensor([-0.0152])
# 294 tensor([4.2003], requires_grad=True)
# 1
# tensor([[-0.0550],
#         [-0.0014]])
# 2
# tensor([0.0031])
# 295 tensor([4.2003], requires_grad=True)
# 1
# tensor([[ 0.0587],
#         [-0.0462]])
# 2
# tensor([0.0127])
# 296 tensor([4.2003], requires_grad=True)
# 1
# tensor([[-0.0179],
#         [ 0.0036]])
# 2
# tensor([0.0658])
# 297 tensor([4.2001], requires_grad=True)
# 1
# tensor([[-0.0469],
#         [-0.0235]])
# 2
# tensor([-0.0035])
# 298 tensor([4.2001], requires_grad=True)
# 1
# tensor([[-0.0464],
#         [ 0.0456]])
# 2
# tensor([0.0296])
# 299 tensor([4.2000], requires_grad=True)
# 1
# tensor([[0.0277],
#         [0.0072]])
# 2
# tensor([0.0150])
# 300 tensor([4.2000], requires_grad=True)
# 1
# tensor([[ 0.0198],
#         [-0.0110]])
# 2
# tensor([-0.0541])
# epoch 3, loss 0.000052

# %% [markdown]
# 因为我们使用的是自己合成的数据集，所以我们知道真正的参数是什么。
# 因此，我们可以通过[**比较真实参数和通过训练学到的参数来评估训练的成功程度**]。
# 事实上，真实参数和通过训练学到的参数确实非常接近。

# %%
print(f'w的估计误差: {true_w - w.reshape(true_w.shape)}')
print(f'b的估计误差: {true_b - b}')
# Out:
# w的估计误差: tensor([-7.6294e-05,  4.3964e-04], grad_fn=<SubBackward0>)
# b的估计误差: tensor([-0.0001], grad_fn=<RsubBackward1>)

# %% [markdown]
# 注意，我们不应该想当然地认为我们能够完美地求解参数。
# 在机器学习中，我们通常不太关心恢复真正的参数，而更关心如何高度准确预测参数。
# 幸运的是，即使是在复杂的优化问题上，随机梯度下降通常也能找到非常好的解。
# 其中一个原因是，在深度网络中存在许多参数组合能够实现高度精确的预测。
#
# ## 小结
#
# * 我们学习了深度网络是如何实现和优化的。在这一过程中只使用张量和自动微分，不需要定义层或复杂的优化器。
# * 这一节只触及到了表面知识。在下面的部分中，我们将基于刚刚介绍的概念描述其他模型，并学习如何更简洁地实现其他模型。
#
# ## 练习
#
# 1. 如果我们将权重初始化为零，会发生什么。算法仍然有效吗？
# 1. 假设试图为电压和电流的关系建立一个模型。自动微分可以用来学习模型的参数吗?
# 1. 能基于[普朗克定律](https://en.wikipedia.org/wiki/Planck%27s_law)使用光谱能量密度来确定物体的温度吗？
# 1. 计算二阶导数时可能会遇到什么问题？这些问题可以如何解决？
# 1. 为什么在`squared_loss`函数中需要使用`reshape`函数？
# 1. 尝试使用不同的学习率，观察损失函数值下降的快慢。
# 1. 如果样本个数不能被批量大小整除，`data_iter`函数的行为会有什么变化？

# %% [markdown]
# [Discussions](https://discuss.d2l.ai/t/1778)
